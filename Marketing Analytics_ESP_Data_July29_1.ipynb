# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
from matplotlib.patches import Patch
import numpy as np
# %matplotlib inline

from category_encoders import *
from IPython.display import display
import scipy.stats as sp
import datetime as dt
import re
#import categorical_embedder
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, RobustScaler, StandardScaler
le = LabelEncoder()
sns.set(rc={'figure.figsize':(14, 8)})

# %%
datainput = pd.read_csv(r"C:\Users\Ighdaro Emwinghare\Downloads\filtered_req_calls.csv")
# Out:
# C:\Users\Ighdaro Emwinghare\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
datainput.T
# Out:
#                                    0                   1        \
# product_id                             NaN                 NaN
# date                            2018-10-05          2020-07-14
# geo_country                            ESP                 ESP
# content_category                       NaN                 NaN
# content_message_local                  NaN                 NaN
# content_message_global                 NaN                 NaN
# product                                NaN                 NaN
# indication                             NaN                 NaN
# therapeutic_area                       NaN                 NaN
# account_id                             NaN                 NaN
# segment_quant                          NaN                 NaN
# segment_qual                           NaN                 NaN
# touchpoint_channel_clm      Face to Face@0     Virtual/Video@0
# measure_source          veeva_interactions  veeva_interactions
#
#                                    2                   3        \
# product_id                             NaN                 NaN
# date                            2020-07-21          2020-07-13
# geo_country                            ESP                 ESP
# content_category                       NaN                 NaN
# content_message_local                  NaN                 NaN
# content_message_global                 NaN                 NaN
# product                                NaN                 NaN
# indication                             NaN                 NaN
# therapeutic_area                       NaN                 NaN
# account_id                             NaN                 NaN
# segment_quant                          NaN                 NaN
# segment_qual                           NaN                 NaN
# touchpoint_channel_clm      Face to Face@0         Telephone@0
# measure_source          veeva_interactions  veeva_interactions
#
#                                                                   4        \
# product_id                                                            NaN
# date                                                           2020-06-29
# geo_country                                                           ESP
# content_category                                                   Safety
# content_message_local   Venclyxto tiene un perfil de seguridad predeci...
# content_message_global  VEN-based regimens have established/manageable...
# product                                                               NaN
# indication                                                            NaN
# therapeutic_area                                                      NaN
# account_id                                                            NaN
# segment_quant                                                         NaN
# segment_qual                                                          NaN
# touchpoint_channel_clm                                        Telephone@0
# measure_source                                         veeva_interactions
#
#                                                                   5        \
# product_id                                                            NaN
# date                                                           2020-07-10
# geo_country                                                           ESP
# content_category                                                   Safety
# content_message_local   Venclyxto tiene un perfil de seguridad predeci...
# content_message_global  VEN-based regimens have established/manageable...
# product                                                               NaN
# indication                                                            NaN
# therapeutic_area                                                      NaN
# account_id                                                            NaN
# segment_quant                                                         NaN
# segment_qual                                                          NaN
# touchpoint_channel_clm                                     Face to Face@0
# measure_source                                         veeva_interactions
#
#                                                                   6        \
# product_id                                                            NaN
# date                                                           2020-07-10
# geo_country                                                           ESP
# content_category                                    AbbVie or Brand Value
# content_message_local   FTD se traduce en: - Eas, - riesgo de aparició...
# content_message_global  VEN regimens are the only chemo-free FTD regim...
# product                                                               NaN
# indication                                                            NaN
# therapeutic_area                                                      NaN
# account_id                                                            NaN
# segment_quant                                                         NaN
# segment_qual                                                          NaN
# touchpoint_channel_clm                                     Face to Face@0
# measure_source                                         veeva_interactions
#
#                                                                   7        \
# product_id                                                            NaN
# date                                                           2020-07-03
# geo_country                                                           ESP
# content_category                                                   Safety
# content_message_local   Venclyxto tiene un perfil de seguridad predeci...
# content_message_global  VEN-based regimens have established/manageable...
# product                                                               NaN
# indication                                                            NaN
# therapeutic_area                                                      NaN
# account_id                                                            NaN
# segment_quant                                                         NaN
# segment_qual                                                          NaN
# touchpoint_channel_clm                                        Telephone@0
# measure_source                                         veeva_interactions
#
#                                    8                   9        ...  \
# product_id                             NaN                 NaN  ...
# date                            2020-07-08          2020-07-13  ...
# geo_country                            ESP                 ESP  ...
# content_category                       NaN                 NaN  ...
# content_message_local                  NaN                 NaN  ...
# content_message_global                 NaN                 NaN  ...
# product                                NaN                 NaN  ...
# indication                             NaN                 NaN  ...
# therapeutic_area                       NaN                 NaN  ...
# account_id                             NaN                 NaN  ...
# segment_quant                          NaN                 NaN  ...
# segment_qual                           NaN                 NaN  ...
# touchpoint_channel_clm         Telephone@0         Telephone@0  ...
# measure_source          veeva_interactions  veeva_interactions  ...
#
#                                        2369662                 2369663  \
# product_id                  a00G000000WC3a8IAD      a00G000000WC3a8IAD
# date                                2017-07-18              2018-04-16
# geo_country                                ESP                     ESP
# content_category                           NaN                     NaN
# content_message_local                      NaN                     NaN
# content_message_global                     NaN                     NaN
# product                 Environment_CLL_KAM_ES  Environment_CLL_KAM_ES
# indication                                 NaN                     NaN
# therapeutic_area                   Hemato/Onco             Hemato/Onco
# account_id                                 NaN                     NaN
# segment_quant                              NaN                     NaN
# segment_qual                               NaN                     NaN
# touchpoint_channel_clm          Face to Face@0          Face to Face@0
# measure_source              veeva_interactions      veeva_interactions
#
#                                        2369664                 2369665  \
# product_id                  a00G000000WC3a8IAD      a00G000000WC3a8IAD
# date                                2017-03-20              2017-01-12
# geo_country                                ESP                     ESP
# content_category                           NaN                     NaN
# content_message_local                      NaN                     NaN
# content_message_global                     NaN                     NaN
# product                 Environment_CLL_KAM_ES  Environment_CLL_KAM_ES
# indication                                 NaN                     NaN
# therapeutic_area                   Hemato/Onco             Hemato/Onco
# account_id                                 NaN                     NaN
# segment_quant                              NaN                     NaN
# segment_qual                               NaN                     NaN
# touchpoint_channel_clm          Face to Face@0          Face to Face@1
# measure_source              veeva_interactions      veeva_interactions
#
#                                        2369666                 2369667  \
# product_id                  a00G000000WC3a8IAD      a00G000000WC3a8IAD
# date                                2017-01-12              2016-11-10
# geo_country                                ESP                     ESP
# content_category                           NaN                     NaN
# content_message_local                      NaN                     NaN
# content_message_global                     NaN                     NaN
# product                 Environment_CLL_KAM_ES  Environment_CLL_KAM_ES
# indication                                 NaN                     NaN
# therapeutic_area                   Hemato/Onco             Hemato/Onco
# account_id                                 NaN                     NaN
# segment_quant                              NaN                     NaN
# segment_qual                               NaN                     NaN
# touchpoint_channel_clm          Face to Face@1          Face to Face@0
# measure_source              veeva_interactions      veeva_interactions
#
#                                        2369668                 2369669  \
# product_id                  a00G000000WC3a8IAD      a00G000000WC3a8IAD
# date                                2018-03-05              2018-09-11
# geo_country                                ESP                     ESP
# content_category                           NaN                     NaN
# content_message_local                      NaN                     NaN
# content_message_global                     NaN                     NaN
# product                 Environment_CLL_KAM_ES  Environment_CLL_KAM_ES
# indication                                 NaN                     NaN
# therapeutic_area                   Hemato/Onco             Hemato/Onco
# account_id                                 NaN                     NaN
# segment_quant                              NaN                     NaN
# segment_qual                               NaN                     NaN
# touchpoint_channel_clm          Face to Face@0          Face to Face@0
# measure_source              veeva_interactions      veeva_interactions
#
#                                        2369670                2369671
# product_id                  a00G000000WC3a8IAD     a00G000000WmJIEIA3
# date                                2018-04-13             2017-11-02
# geo_country                                ESP                    ESP
# content_category                           NaN                    NaN
# content_message_local                      NaN                    NaN
# content_message_global                     NaN                    NaN
# product                 Environment_CLL_KAM_ES  Venetoclax_AML_MED_ES
# indication                                 NaN                    NaN
# therapeutic_area                   Hemato/Onco            Hemato/Onco
# account_id                                 NaN                    NaN
# segment_quant                              NaN                    NaN
# segment_qual                               NaN                    NaN
# touchpoint_channel_clm          Face to Face@0         Face to Face@0
# measure_source              veeva_interactions     veeva_interactions
#
# [14 rows x 2369672 columns]

# %%
#since we are interested in analyizing different product_ids, it is necessary to drop rows that contain null as product_id
data = datainput
data  = data.dropna(axis=0, subset=['product_id'])

# %%
data.isnull().sum()
# Out:
# product_id                      0
# date                            0
# geo_country                     0
# content_category          2238795
# content_message_local     2238795
# content_message_global    2238795
# product                         0
# indication                 551394
# therapeutic_area           190606
# account_id                1008886
# segment_quant             1304636
# segment_qual              1568067
# touchpoint_channel_clm          0
# measure_source                  0
# dtype: int64

# %%
print(dict(data['product_id'].value_counts()))
# Out:
# {'a00G000000URPpMIAX': 204442, 'a00G000000VfomnIAB': 201880, 'a00G000000URPplIAH': 178445, 'a00G000000URPpNIAX': 157414, 'a00G000000URPpHIAX': 152666, 'a00G000000URPpkIAH': 112207, 'a00G000000URPpGIAX': 104640, 'a00G000000URPpJIAX': 102859, 'a00G000000URPpnIAH': 101872, 'a00G000000URPppIAH': 94134, 'a00G000000URPpOIAX': 66973, 'a00G000000URsmCIAT': 61428, 'a00G000000URsmBIAT': 47585, 'a001v00001cTVBIAA4': 47464, 'a00G000000Ux9H6IAJ': 45956, 'a000Y00000DLyrGQAT': 45722, 'a00G000000WC3H4IAL': 44031, 'a001v00001cTVB8AAO': 39493, 'a00G000000URsmDIAT': 29959, 'a00G000000URPpLIAX': 29281, 'a00G000000URPpmIAH': 27662, 'a00G000000URPpoIAH': 26877, 'a001v000021iYhHAAU': 23272, 'a00G000000URPpIIAX': 20243, 'a001v00001wbtlnAAA': 19103, 'a00G000000UyIoSIAV': 19068, 'a00G000000URPpKIAX': 18142, 'a00G000000URPpXIAX': 16860, 'a00G000000URsmEIAT': 15179, 'a001v00001cTVAVAA4': 13811, 'a000Y00000HX2tsQAD': 12542, 'a00G000000WC3a7IAD': 12072, 'a00G000000URPpeIAH': 8859, 'a00G000000UymzOIAR': 8762, 'a000Y00000A0BG1QAN': 7819, 'a001v00001cTVAfAAO': 7337, 'a00G000000WC3a6IAD': 6827, 'a00G000000URPpsIAH': 6061, 'a00G000000UymzPIAR': 6056, 'a00G000000W9d5fIAB': 5103, 'a000Y00000HX2trQAD': 4951, 'a000Y00000HX2ttQAD': 4828, 'a00G000000Ux9H5IAJ': 4742, 'a00G000000URPpFIAX': 4708, 'a00G000000URPpYIAX': 4534, 'a00G000000WC3a8IAD': 4355, 'a00G000000URPpWIAX': 4042, 'a000Y00000DLyrIQAT': 3833, 'a001v00001f89HUAAY': 3531, 'a00G000000URPpiIAH': 3080, 'a00G000000URPpPIAX': 2971, 'a000Y00001CirgbQAB': 2743, 'a000Y00000GBAq0QAH': 2626, 'a000Y00000A1Hy9QAF': 2625, 'a00G000000URPpwIAH': 2524, 'a000Y00000DLyrHQAT': 2314, 'a00G000000URPpQIAX': 2223, 'a00G000000UxNmyIAF': 2206, 'a00G000000URPpgIAH': 2120, 'a000Y00001CirfoQAB': 2084, 'a00G000000URPpTIAX': 1985, 'a001v00001cTV9xAAG': 1974, 'a000Y00001CirfAQAR': 1821, 'a00G000000URPpyIAH': 1581, 'a000Y00001CirfnQAB': 1556, 'a000Y00001CirffQAB': 1540, 'a00G000000URPpUIAX': 1506, 'a000Y00001CirfeQAB': 1477, 'a001v000022LcG1AAK': 1477, 'a00G000000URPpuIAH': 1469, 'a000Y00001CirgaQAB': 1405, 'a00G000000URPpSIAX': 1405, 'a000Y000009zN7JQAU': 1348, 'a00G000000URPpxIAH': 1340, 'a00G000000URPpRIAX': 1315, 'a000Y00001CirgWQAR': 1302, 'a00G000000URPpZIAX': 1266, 'a000Y00001CirgUQAR': 1182, 'a000Y00000pYJKSQA4': 1165, 'a00G000000URPpaIAH': 1155, 'a000Y00001CirfHQAR': 1134, 'a000Y00001CirfZQAR': 999, 'a00G000000URPpVIAX': 871, 'a00G000000URPphIAH': 750, 'a00G000000UxNmwIAF': 739, 'a00G000000URPpjIAH': 683, 'a000Y00001Cirf8QAB': 563, 'a000Y00001CirfJQAR': 518, 'a000Y00001CirfmQAB': 504, 'a000Y00001CirfQQAR': 500, 'a000Y00001CirflQAB': 493, 'a00G000000URPpdIAH': 426, 'a000Y000009zlEbQAI': 408, 'a00G000000URPprIAH': 370, 'a00G000000URPpcIAH': 370, 'a000Y00001CirfIQAR': 341, 'a000Y00001CirfKQAR': 253, 'a000Y00001CirfRQAR': 225, 'a000Y00001CirgPQAR': 219, 'a000Y00001Cirf9QAB': 202, 'a00G000000UxNn1IAF': 202, 'a000Y00001CirfkQAB': 196, 'a000Y00001Cirf4QAB': 171, 'a00G000000Wm0uLIAR': 171, 'a00G000000WmiooIAB': 159, 'a000Y00001Cirf0QAB': 149, 'a000Y00001Cirf5QAB': 139, 'a000Y00001CirfTQAR': 132, 'a00G000000WmJIEIA3': 129, 'a000Y00001CirfYQAR': 125, 'a00G000000URPq2IAH': 124, 'a001v00002KOFeUAAX': 114, 'a000Y00001CirfSQAR': 102, 'a00G000000UxNmzIAF': 101, 'a000Y00000CiMfZQAV': 100, 'a000Y00001CirgRQAR': 99, 'a000Y00001CirfxQAB': 99, 'a00G000000WmionIAB': 92, 'a000Y00001CirfzQAB': 90, 'a00G000000URPq1IAH': 86, 'a00G000000WC3aAIAT': 85, 'a000Y000009zlEdQAI': 79, 'a00G000000UzMNgIAN': 72, 'a000Y00001CirezQAB': 67, 'a00G000000URPptIAH': 64, 'a000Y00001CirgNQAR': 64, 'a001v00001cTVAUAA4': 61, 'a000Y00001CirgBQAR': 58, 'a000Y00001CirgIQAR': 58, 'a000Y00001CirgTQAR': 51, 'a000Y00000HX2u1QAD': 50, 'a00G000000URPq3IAH': 48, 'a000Y00001CirgJQAR': 47, 'a000Y00001CirfMQAR': 46, 'a00G000000URPpbIAH': 43, 'a000Y00001CirgQQAR': 40, 'a000Y00001CirfrQAB': 36, 'a000Y00001CirgSQAR': 35, 'a000Y00001IsHBEQA3': 35, 'a000Y00001IsHBFQA3': 32, 'a000Y00000GBAq1QAH': 30, 'a000Y00001IsHBGQA3': 30, 'a000Y00001CirfNQAR': 30, 'a000Y00001Cirg4QAB': 30, 'a000Y00001IsHB4QA ...

# %%
data['monthyear'] = pd.to_datetime(datainput['date']).dt.to_period('M')
# Out:
# C:\Users\Ighdaro Emwinghare\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
#fill missing values with specific indicator.
data['content_category'] = data['content_category'].fillna('Unknown')
data['touchpoint_channel_clm'] = data['touchpoint_channel_clm'].fillna('Unknown')
data['content_message_local'] = data['content_message_local'].fillna('NoMessage')
data['content_message_global'] = data['content_message_global'].fillna('NoMessage')
# Out:
# C:\Users\Ighdaro Emwinghare\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Ighdaro Emwinghare\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Ighdaro Emwinghare\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Ighdaro Emwinghare\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
dict(data['content_message_local'].value_counts())
# Out:
# {'NoMessage': 2238795,
#  'Aclaramiento completo duradero': 5851,
#  'Facilidad': 5433,
#  'Seguridad': 5201,
#  'Ibrutinib es una buena ocpion de rescate para los pac que progresan tras Ven': 1594,
#  'Campaña Nada lo cambia todo': 648,
#  'Compromiso de Abbvie con la hematología': 524,
#  'Perspectivas en LLC': 433,
#  'Adherencia': 404,
#  'Aclaramiento duradero con independencia de las características basales': 391,
#  'Aclaramiento duradero superior a Stelara': 360,
#  'Eficacia y tolerabilidad vs otros MOAs': 228,
#  'Local Key Message does not apply': 216,
#  'VenR es la única alternativa que permite lFTD a los 2 años: - coste': 209,
#  '1º y único inhibidor potente y selectivo de BCL2': 197,
#  'Venclyxto tiene un perfil de seguridad predecible y manejable': 160,
#  '87% de los pac. con EMR-, permanecieron libres de progresión tras 4 años': 132,
#  'Más de la mitad de los pacientes con VenR continúan sin progresar a los 4 años': 125,
#  'FTD se traduce en: - Eas, - riesgo de aparición de resist, + adherencia, + QoL': 123,
#  'VenR demostró superioridad en SLP en todos los subgrupos de pacientes': 99,
#  '6 de cada 10 pacientes con Venclyxto + rituximab alcanzaron EMR-': 89,
#  'Adherencia/AC': 39,
#  'Aclaramiento duradero superior a adalimumab': 13,
#  'Skyrizi/IL-23 MOA': 12,
#  'Mejora de la CdV; Guias de tratamiento': 8,
#  'Diseño de los ensayos clínicos': 2}

# %%
dict(data['content_message_global'].value_counts())
# Out:
# {'NoMessage': 2238795,
#  'Durable complete clearance': 5851,
#  'Reliable 3-month dosing regardless of baseline characteristics': 5824,
#  'SKYRIZI/IL-23 MOA': 5441,
#  'Global Key message does not apply': 2118,
#  'VEN regimens are the only chemo-free FTD regimens & offer multiple benefits': 765,
#  'Nothing is Everything/campaign summary': 648,
#  'The potential of SKYRIZI can only be achieved if patients adhere to\xa0treatment': 404,
#  'Durable clearance superior to Stelara': 360,
#  'MURANO: The PFS benefit of VEN+R vs BR was sustained at 4-year follow-up': 224,
#  'Global Key Message does not apply': 216,
#  'VEN is a selective, oral, BCL-2 inhibitor that restores the process of apoptosis': 197,
#  'VEN-based regimens have established/manageable safety profile in CLL  trials': 160,
#  'Achieving deep response is important & may be associated with improved outcomes': 132,
#  'MURANO: VEN+R induced deep responses in many patients': 89,
#  'AC is specifically designed for SKYRIZI patients to optimize their\xa0adherence': 39,
#  'Durable clearance superior to adalimumab': 13,
#  'Improved QoL; Treatment guidelines': 8,
#  'Skyrizi trial designs': 2}

# %%
#reform the content_message_concat by combining content_message_Local, 'sgm' and content_message_global
data['tactic'] = data['content_message_local'] + ' SGM ' + data['content_message_global']
# Out:
# C:\Users\Ighdaro Emwinghare\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data['tactic'].nunique()
# Out:
# 26

# %%
data['tactic'].value_counts()
# Out:
# NoMessage SGM NoMessage                                                                                                                                           2238795
# Aclaramiento completo duradero SGM Durable complete clearance                                                                                                        5851
# Facilidad SGM Reliable 3-month dosing regardless of baseline characteristics                                                                                         5433
# Seguridad SGM SKYRIZI/IL-23 MOA                                                                                                                                      5201
# Ibrutinib es una buena ocpion de rescate para los pac que progresan tras Ven SGM Global Key message does not apply                                                   1594
# Campaña Nada lo cambia todo SGM Nothing is Everything/campaign summary                                                                                                648
# Compromiso de Abbvie con la hematología SGM Global Key message does not apply                                                                                         524
# Perspectivas en LLC SGM VEN regimens are the only chemo-free FTD regimens & offer multiple benefits                                                                   433
# Adherencia SGM The potential of SKYRIZI can only be achieved if patients adhere to treatment                                                                          404
# Aclaramiento duradero con independencia de las características basales SGM Reliable 3-month dosing regardless of baseline characteristics                             391
# Aclaramiento duradero superior a Stelara SGM Durable clearance superior to Stelara                                                                                    360
# Eficacia y tolerabilidad vs otros MOAs SGM SKYRIZI/IL-23 MOA                                                                                                          228
# Local Key Message does not apply SGM Global Key Message does not apply                                                                                                216
# VenR es la única alternativa que permite lFTD a los 2 años: - coste SGM VEN regimens are the only chemo-free FTD regimens & offer multiple benefits                   209
# 1º y único inhibidor potente y selectivo de BCL2 SGM VEN is a selective, oral, BCL-2 inhibitor that restores the process of apoptosis                                 197
# Venclyxto tiene un perfil de seguridad predecible y manejable SGM VEN-based regimens have established/manageable safety profile in CLL  trials                        160
# 87% de los pac. con EMR-, permanecieron libres de progresión tras 4 años SGM Achieving deep response is important & may be associated with improved outcomes          132
# Más de la mitad de los pacientes con VenR continúan sin progresar a los 4 años SGM MURANO: The PFS benefit of VEN+R vs BR was sustained at 4-year follow-up           125
# FTD se traduce en: - Eas, - riesgo de aparición de resist, + adherencia, + QoL SGM VEN regimens are the only chemo-free FTD regimens & offer multiple benefits        123
# VenR demostró superioridad en SLP en todos los subgrupos de pacientes SGM MURANO: The PFS benefit of VEN+R vs BR was sustained at 4-year follow-up                     99
# 6 de cada 10 pacientes con Venclyxto + rituximab alcanzaron EMR- SGM MURANO: VEN+R induced deep responses in many patients                                             89
# Adherencia/AC SGM AC is specifically designed for SKYRIZI patients to optimize their adherence                                                                         39
# Aclaramiento duradero superior a adalimumab SGM Durable clearance superior to adalimumab                                                                               13
# Skyrizi/IL-23 MOA SGM SKYRIZI/IL-23 MOA                                                                                                                                12
# Mejora de la CdV; Guias de tratamiento SGM Improved QoL; Treatment guidelines                                                                                           8
# Diseño de los ensayos clínicos SGM Skyrizi trial designs                                                                                                                2
# Name: tactic, dtype: int64

# %%
data.isnull().sum()/len(data)

#99% values in tactic, content_category, content_message_local and content_message_global are missing.
# Out:
# product_id                0.000000
# date                      0.000000
# geo_country               0.000000
# content_category          0.000000
# content_message_local     0.000000
# content_message_global    0.000000
# product                   0.000000
# indication                0.243841
# therapeutic_area          0.084291
# account_id                0.446156
# segment_quant             0.576944
# segment_qual              0.693440
# touchpoint_channel_clm    0.000000
# measure_source            0.000000
# monthyear                 0.000000
# tactic                    0.000000
# dtype: float64

# %%
data.columns
# Out:
# Index(['product_id', 'date', 'geo_country', 'content_category',
#        'content_message_local', 'content_message_global', 'product',
#        'indication', 'therapeutic_area', 'account_id', 'segment_quant',
#        'segment_qual', 'touchpoint_channel_clm', 'measure_source', 'monthyear',
#        'tactic'],
#       dtype='object')

# %%
"""Helper Functions"""


def get_cat_feats(data=None):
    '''
    Returns the categorical features in a data set
    Parameters:
    -----------
        data: DataFrame or named Series 
    Returns:
    -------
        List
            A list of all the categorical features in a dataset.
    it is used as a helper function for most of the functions to get categorical variables
    '''
    if data is None:
        raise ValueError("data: Expecting a DataFrame or Series, got 'None'")

    cat_features = data.select_dtypes(include=['object']).columns

    return list(cat_features)
def get_num_feats(data=None):
    '''
    Returns the numerical features in a data set
    Parameters:
    -----------
        data: DataFrame or named Series 
    Returns:
    -------
        List:
            A list of all the numerical features in a dataset.
    it is used as a helper function for most of the functions to get categorical variables
    '''
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

    if data is None:
        raise ValueError("data: Expecting a DataFrame or Series, got 'None'")

    num_features = data.select_dtypes(include=numerics).columns

    return list(num_features)
def get_unique_counts(data=None):
    '''
    Gets the unique count of categorical features in a data set.
    Parameters
    -----------
        data: DataFrame or named Series 
    Returns
    -------
        DataFrame or Series
            Unique value counts of the features in a dataset.
    it is used as a helper function in the describe function to get the count of unique values in the columns 
    '''

    if data is None:
        raise ValueError("data: Expecting a DataFrame or Series, got 'None'")

    features = get_cat_feats(data)
    temp_len = []

    for feature in features:
        temp_len.append(len(data[feature].unique()))
        
    df = list(zip(features, temp_len))
    df = pd.DataFrame(df, columns=['Feature', 'Unique Count'])
    df = df.style.bar(subset=['Unique Count'], align='mid')
    return df
def display_missing(data=None, plot=False):
    '''
    Display missing values as a pandas dataframe.
    Parameters
    ----------
        data: DataFrame or named Series
        plot: bool, Default False
            Plots missing values in dataset as a heatmap
    
    Returns
    -------
        Matplotlib Figure:
            Heatmap plot of missing values
    '''

    if data is None:
        raise ValueError("data: Expecting a DataFrame or Series, got 'None'")

    df = data.isna().sum()
    df = df.reset_index()
    df.columns = ['features', 'missing_counts']

    missing_percent = round((df['missing_counts'] / data.shape[0]) * 100, 1)
    df['missing_percent'] = missing_percent

    if plot:
        plot_missing(data)
        return df
    else:
        return df
    
def cat_summarizer(data, x=None, y=None, hue=None, palette='Set1', verbose=True):
    '''
    Helper function that gives a quick summary of a given column of categorical data
    Parameters:
    ---------------------------
        dataframe: pandas dataframe
        x: str.
            horizontal axis to plot the labels of categorical data, y would be the count.
        y: str. 
            vertical axis to plot the labels of categorical data, x would be the count.
        hue: str. i
            if you want to compare it another variable (usually the target variable)
        palette: array, list.
            Colour of the plot
    Returns:
    ----------------------
        Quick Stats of the data and also the count plot
        
        it is used in the describe function
    '''
    if x == None:
        column_interested = y
    else:
        column_interested = x
    series = data[column_interested]
    print(series.describe())
    print('mode: ', series.mode())
    if verbose:
        print('='*80)
        print(series.value_counts())

    sns.countplot(x=x, y=y, hue=hue, data=data, palette=palette)
    plt.show()
    
def _space():
    '''it is used in  most functions to add space. this makes result more presentation'''
    print('\n')
def _match_date(data):
    '''
        Return a list of columns that matches the DateTime expression
    '''
    mask = data.sample(20).astype(str).apply(lambda x : x.str.match(r'(\d{2,4}-\d{2}-\d{2,4})+').all())
    return set(data.loc[:, mask].columns)


def display_rows(data,num=2):
    '''
    Displays the required number of rows
    it is used in the describe function
    '''
    if data is None:
        raise ValueError("data: Expecting a DataFrame/ numpy2d array, got 'None'")

    return data.head(num)

def plot_missing(data=None):
    '''
    Plots the data as a heatmap to show missing values
    Parameters
    ----------
        data: DataFrame, array, or list of arrays.
            The data to plot.
    '''

    if data is None:
        raise ValueError("data: Expecting a DataFrame or Series, got 'None'")

    sns.heatmap(data.isnull(), cbar=True)
    plt.show()
    
def class_count(data=None, features=None, plot=False, save_fig=False):
    '''
    Displays the number of classes in a categorical feature.
    Parameters:
    
        data: Pandas DataFrame or Series
            Dataset for plotting.
        features: Scalar, array, or list. 
            The categorical features in the dataset, if None, 
            we try to infer the categorical columns from the dataframe.
        plot: bool, Default False.
            Plots the class counts as a barplot
        save_fig: bool, Default False.
            Saves the plot to the current working directory.
    it is used in the describe function
    '''

    if data is None:
        raise ValueError("data: Expecting a DataFrame or Series, got 'None'")

    if features is None:
        features = get_cat_feats(data)

                        

    for feature in features:
        if data[feature].nunique() > 15:
            print("Unique classes in {} too large".format(feature))
        else:
            print('Class Count for', feature)
            display(pd.DataFrame(data[feature].value_counts()))

    if plot:
        countplot(data, features, save_fig=save_fig)
        
def get_date_cols(data=None):
    '''
    Returns the Datetime columns in a data set.
    Parameters
    ----------
        data: DataFrame or named Series
            Data set to infer datetime columns from.
        convert: bool, Default True
            Converts the inferred date columns to pandas DateTime type
    Returns:
    -------
        List
         Date column names in the data set
    use in the describe function to set date columns to datetime datatype in utc
    '''

    if data is None:
        raise ValueError("data: Expecting a DataFrame or Series, got 'None'")

    #Get existing date columns in pandas Datetime64 format
    date_cols = set(data.dtypes[data.dtypes == 'datetime64[ns, UTC]'].index)
    #infer Date columns 
    date_cols = date_cols.union(_match_date(data))
       
    return date_cols

def bivariate_stats(data):
    '''Returns the contingency table and chi2 contingency test result between columns in the dataframe
        
        it is used in the describe function for categorical features analysis 
    
    
    '''
    cat_feats = get_cat_feats(data=data)
    counter = 1
    try:
        while counter<(len(cat_feats)):
            val1 = get_cat_feats(data=datainput)[counter - 1]
            val2 = get_cat_feats(data=datainput)[counter]
            if (data[val1].nunique() > 15) or (data[val2].nunique() > 15):
                print('Number of unique values too large')
            else:
                freqtab = pd.crosstab(data[val1], data[val2])
                print("Frequency table")
                print("============================")
                print(freqtab)
                print("============================")
                chi2, pval, dof, expected = sp.chi2_contingency(freqtab)
                print("ChiSquare test statistic: ",chi2)
                print("p-value: ",pval)
                _space()
            counter= counter+1
    except:
        pass
    
def bivariate_stats_target(data, target):
    
    '''Returns the contingency table and chi2 contingency test result between columns and the target variable in the dataframe
        
        
        Parameters
    ----------
        data: DataFrame or named Series
            Data set to infer datetime columns from.
        target: the target variable in form of string

        
        it is used in the describe function for categorical features analysis of the relationship between the target variable 
        and other categorical features
    
    
    '''
    cat_feats = get_cat_feats(data=data)
    for i in cat_feats:
        if (data[i].nunique() > 20):
            print('Number of Unique values too large')
        else:
            freqtab = pd.crosstab(data[i], data[target])
            print("Frequency table")
            print("============================")
            print(freqtab)
            print("============================")
            chi2, pval, dof, expected = sp.chi2_contingency(freqtab)
            print("ChiSquare test statistic: ",chi2)
            print("p-value: ",pval)
            _space()
            
def describe(data=None, name='', date_cols=None, show_categories=False, plot_missing=False, target = None):
    '''
    Calculates statistics and information about a data set. Information displayed are
    shapes, size, number of categorical/numeric/date features, missing values,
    dtypes of objects, correlation analysis, contigency analysis etc.
    Parameters:
    --------------------
        data: Pandas DataFrame
            The data to describe.
        name: str, optional
            The name of the data set passed to the function.
        date_cols: list/series/array
            Date column names in the data set.
        show_categories: bool, default False
            Displays the unique classes and counts in each of the categorical feature in the data set.
        plot_missing: bool, default True
            Plots missing values as a heatmap
        target: the target variable in the dataframe
    Returns:
    -------
        None
        
        This function is stand alone use for quick statistical exploration of the data.
    '''
    
    if data is None:
        raise ValueError("data: Expecting a DataFrame or Series, got 'None'")

    ## Get categorical features
    cat_features = get_cat_feats(data)
    
    #Get numerical features
    num_features = get_num_feats(data)

    print('First five data points')
    display(data.head())
    _space()

    print('Random five data points')
    display(data.sample(5))
    _space()

    print('Last five data points')
    display(data.tail())
    _space()

    print('Shape of {} data set: {}'.format(name, data.shape))
    _space()

    print('Size of {} data set: {}'.format(name, data.size))
    _space()

    print('Data Types')
    print("Note: All Non-numerical features are identified as objects in pandas")
    display(pd.DataFrame(data.dtypes, columns=['Data Type']))
    _space()
    
    date_cols = get_date_cols(data)
    if len(date_cols) is not 0:
        print("Column(s) {} should be in Datetime format. Use the [to_date] function to convert to Pandas Datetime format".format(date_cols))
        _space()

    print('Numerical Features in Data set')
    print(num_features)
    _space()

    print('Categorical Features in Data set')
    display(cat_features)
    _space()

    print('Statistical Description of Columns')
    display(data.describe())
    _space()
    
    print('Description of Categorical Features')
    if cat_features != None:
        display(data.describe(include=[np.object, pd.Categorical]).T)
        _space()
          
    print('Unique class Count of Categorical features')
    display(get_unique_counts(data))
    _space()

    if show_categories:     
        print('Classes in Categorical Columns')
        print("-"*30)
        class_count(data, cat_features)
        _space()

    print('Missing Values in Data')
    display(display_missing(data))
    _space()
  
    print('Pearson Correlation')
    print(data.corr())
    _space()
    
    print('Kendall Correlation')
    print(data.corr(method='kendall'))
    _space()
    
    print('Spearman Correlation')
    print(data.corr(method='spearman'))
    _space()
    
    print('Bivariant Stats between categorical features')
    print(bivariate_stats(data))
    _space()
    if target is not None:
        print('Bivariant Stats between cat feats and target variable')
        print(bivariate_stats_target(data, target))
        _space()
    print('')
    

def drop_missing(data=None, percent=99):
    '''
    Drops missing columns with [percent] of missing data.
    Parameters:
    -------------------------
        data: Pandas DataFrame or Series.
        percent: float, Default 99
            Percentage of missing values to be in a column before it is eligible for removal.
    Returns:
    ------------------
        Pandas DataFrame or Series.
    It can be used alone. It also used in deal_with_missing_value function.
    
    This function is used in the deal_with_missing_value function.
    '''

    if data is None:
        raise ValueError("data: Expecting a DataFrame/ numpy2d array, got 'None'")
    
    missing_percent = (data.isna().sum() / data.shape[0]) * 100
    cols_2_drop = missing_percent[missing_percent.values >= percent].index
    print("Dropped {}".format(list(cols_2_drop)))
    #Drop missing values
    df = data.drop(cols_2_drop, axis=1)
    return df

def fill_missing_cats(data=None, cat_features=None, missing_encoding=None, missing_col=False):
    '''
    Fill missing values using the mode of the categorical features.
    Parameters:
    ------------------------
        data: DataFrame or name Series.
            Data set to perform operation on.
        cat_features: List, Series, Array.
            categorical features to perform operation on. If not provided, we automatically infer the categoricals from the dataset.
        missing_encoding: List, Series, Array.
            Values used in place of missing. Popular formats are [-1, -999, -99, '', ' ']
        missin_col: bool, Default True
      Creates a new column to capture the missing values. 1 if missing and 0 otherwise. This can sometimes help a machine learning model.
      
      This function is used in the deal_with_missing_value function.
    '''

    if data is None:
        raise ValueError("data: Expecting a DataFrame/ numpy2d array, got 'None'")

    if cat_features is None:
        cat_features = get_cat_feats(data)

    df = data.copy()
    #change all possible missing values to NaN
    if missing_encoding is None:
        missing_encoding = ['', ' ', -99, -999]

    df.replace(missing_encoding, np.NaN, inplace=True)
    
    for feat in cat_features:
        if missing_col:
            df[feat + '_missing_value'] = (df[feat].isna()).astype('int64')
        most_freq = df[feat].mode()[0]
        df[feat] = df[feat].replace(np.NaN, most_freq)
    
    return df

def fill_missing_num(data=None, num_features=None, method='mean', missing_col=False):
    '''
    fill missing values in numerical columns with specified [method] value
    Parameters:
        ------------------------------
        data: DataFrame or name Series.
            The data set to fill
        features: list.
            List of columns to fill
        method: str, Default 'mean'.
            method to use in calculating fill value.
        missing_col: bool, Default True
          Creates a new column to capture the missing values. 1 if missing and 0 otherwise. This can sometimes help a machine learning model.
          
          This function is used in the deal_with_missing_value function.
    '''
    if data is None:
        raise ValueError("data: Expecting a DataFrame/ numpy2d array, got 'None'")
    
    if num_features is None:
        num_features = get_num_feats(data)
        #get numerical features with missing values
        temp_df = data[num_features].isna().sum()
        features = list(temp_df[num_features][temp_df[num_features] > 0].index)
        
    df = data.copy()
    for feat in features:
        if missing_col:
            df[feat + '_missing_value'] = (df[feat].isna()).astype('int64')
        if method is 'mean':
            mean = df[feat].mean()
            df[feat].fillna(mean, inplace=True)
        elif method is 'median':
            median = df[feat].median()
            df[feat].fillna(median, inplace=True)
        elif method is 'mode':
            mode = df[feat].mode()[0]
            df[feat].fillna(mode, inplace=True)
        else:
            raise ValueError("method: must specify a fill method, one of [mean, mode or median]'")
    return df

def deal_with_missing_value(data, percent=70):
    """
    this function automatically take care of missing values.
        It fills the missing values in categorical variables with mode of the particular column
        and fills the missing value numerical variables with mean of the particular column.
        It automatically drops columns with more than 70% missing values except when set otherwise.
        
        This function is used in the feature_preprocessing function to deal with missing values. It can also be used alone.
        """
    if data is None:
        raise ValueError("data: Expecting a DataFrame/ numpy2d array, got 'None'")
    df1 = drop_missing(data=data, percent=percent)
    df2 = fill_missing_cats(data=df1)
    df = fill_missing_num(data=df2)
    return df

def drop_redundant(data):
    '''
    Removes features with the same value in all cell. Drops feature If Nan is the second unique class as well.
    Parameters:
    -----------------------------
        data: DataFrame or named series.
    
    Returns:
        DataFrame or named series.
    This function is used in the feature_processing function.
    '''

    if data is None:
        raise ValueError("data: Expecting a DataFrame/ numpy2d array, got 'None'")
    
    #get columns
    cols_2_drop = _nan_in_class(data)
    print("Dropped {}".format(cols_2_drop))
    df = data.drop(cols_2_drop, axis=1)
    return df
def _nan_in_class(data):
    """helper function for drop_redundant function"""
    cols = []
    for col in data.columns:
        if len(data[col].unique()) == 1:
            cols.append(col)

        if len(data[col].unique()) == 2:
            if np.nan in list(data[col].unique()):
                cols.append(col)

    return cols

#Label Encoding for object to numeric conversion
def binaryencoder(data):
    """To avoid the curse of dimensionality, this function only encodes categorical features with less than 7 unique values
    
        This function can be used alone. It is also used in the encode_data function.
        
        It is the default method for encoding categorical variables with unique value less than four in the encode_data function.
        
        explanation: It is similar to onehot encoding but gives lesser dimensions, making it a better option. 
                    It converts the unique entry into binary combination and then creates column using binary hashing.
    """
    features = get_cat_feats(data=data)
    cols = []
    for feature in features:
        if data[feature].nunique() < 7:
            cols.append(feature)
        
    enc = BinaryEncoder(cols=cols).fit(data)
    data = enc.transform(data)
    return data

def onehotencoder(data):
    """To avoid the curse of dimensionality, this function only encodes categorical features with less than 4 unique values
    
        This function can be used alone. It is also used in the encode_data function
        
    The onehotencoder is only used when the number of unique value is less than four to avoid the curse of dimensionality.
    If encode_data method parameter is set to 'onehotencode' this is what is used in encoding categorical variables with 
    number of unique values less than 4.
    
    explanation: it is used mostly for nominal variables such that a binary combination of the unique values are set as new columns
                    in the dataset.
    """
    features = get_cat_feats(data=data)
    cols = []
    for feature in features:
        if data[feature].nunique() < 4:
            cols.append(feature)
        
    enc = OneHotEncoder(cols=cols).fit(data)
    data = enc.transform(data)
    return data

def labelencoder(data):
    """
    This function can be used alone. It is also used in the encode_data function.
    
    It is used for columns that has more than 3 unique values. Such columns are treated as ordinal variables. 
    
    Explanation: Label encoders are ordinal encoders that encode unique values as continuous intergers.
    
    """
    features = get_cat_feats(data=data)
    for feat in features:
        data[feat] = le.fit_transform(data[feat].astype(str))
    return data

def sumencoder(data):
    """
    This function can be used alone. It is also used in the encode_data function.
    
    The sumencoder is only used when the number of unique value is less than four to avoid the curse of dimensionality.
    If encode_data method parameter is set to 'sumencode' this is what is used in encoding categorical variables with 
    number of unique values less than 4.
    
    explanation: it is similar to one-hot encoding but the difference is that in sum encoding one value is taken as '-1'
                and it is not compared to other value.
    """

    features = get_cat_feats(data=data)
    cols = []
    for feature in features:
        if data[feature].nunique() < 4:
            cols.append(feature)
    enc = SumEncoder(cols = cols).fit_transform(data)
    data = enc
    return data

def catboostencoder(data, target):
    '''Data inputs must not be string
        This function is used alone. It is not called by any other function.
        
        it uses the catboost tree model in properly encoding categorical features.
    
        explanation: a target encoder. It uses the target variable in encoding the categorical variables. 
        It is more accurate than most encoding methods.
    '''
    X = data.drop(target, axis=1)
    y = data[target]
    features = get_cat_feats(data=X)
    enc = CatBoostEncoder(cols=features).fit(X,y)
    data = enc.transform(X, y)
    return data

def hashencoder(data):
    '''
         This function can be used alone. It is also used in the encode_data function.
    
        The hashencoder is only used when the number of unique value is less than four to avoid the curse of dimensionality.
        If encode_data method parameter is set to 'hashencode' this is what is used in encoding categorical variables with 
        number of unique values less than 4.

        explanation: Feature hashing maps each category in a categorical feature to an integer within a predetermined range
    
                        The size of the output dimensions is controlled by the variable n_components.
    '''    
    
    cols = get_cat_feats(data)
    new_col = []
    for i in cols:
        string = str(data[i][0]) + str(data[i][len(data)-1]) 
        flag = re.findall(r'\d+', string)
        if len(flag) > 2:
               if len(flag[0])>2:
                    new_col.append(i)
        
    enc = HashingEncoder(cols=new_col, n_components= 1).fit(data)
    data = enc.transform(data)
    
    return data

def embeddingencoder(data):
     """
        This function is used alone.
        It uses neural network embeddings to encode categorical features. 
         """
     embedding_info = ce.get_embedding_info(data)
     X_encoded,encoders = ce.get_label_encoded_data(data)

     return X_endoded

def encode_data(data, method='binary'):
    """
        encodes categorical variables automatically using binary encoding for columns with less than 4 unique values
        then label encode all other variables
        method takes either binary or onehot or sumencode or hashcode. default is binary
        
        this function can be used alone and it also used in the feature_processing function.
        
        
    """
    if method == 'binary':
        data = binaryencoder(data)
    elif method== 'onehot':
        data = onehotencoder(data)
    elif method == 'sumencode':
        data = sumencode(data)
    data = labelencoder(data)
    return data

# %%
data = deal_with_missing_value(data, percent=60)
# Out:
# Dropped ['segment_qual']

# %%
#data = drop_redundant(data)

# %%
describe(data=data, name='', date_cols=None, show_categories=False, plot_missing=False, target = None)
# Out:
# First five data points
#              product_id        date geo_country content_category  \
# 548  a000Y00000A0BG1QAN  2017-05-10         ESP          Unknown
# 549  a000Y00000A0BG1QAN  2017-05-10         ESP          Unknown
# 550  a000Y00000A0BG1QAN  2018-03-09         ESP          Unknown
# 551  a000Y00000A0BG1QAN  2018-03-09         ESP          Unknown
# 552  a000Y00000A0BG1QAN  2018-03-09         ESP          Unknown
#
#     content_message_local content_message_global                   product  \
# 548             NoMessage              NoMessage  Abbvie Care Pediatría_ES
# 549             NoMessage              NoMessage  Abbvie Care Pediatría_ES
# 550             NoMessage              NoMessage  Abbvie Care Pediatría_ES
# 551             NoMessage              NoMessage  Abbvie Care Pediatría_ES
# 552             NoMessage              NoMessage  Abbvie Care Pediatría_ES
#
#         indication therapeutic_area          account_id segment_quant  \
# 548  No indication          Care_ES  001G000001tCWu5IAG            B2
# 549  No indication          Care_ES  001G000001tCWu5IAG            B2
# 550  No indication          Care_ES  001G000001tCWu5IAG            B2
# 551  No indication          Care_ES  001G000001tCWu5IAG            B2
# 552  No indication          Care_ES  001G000001tCWu5IAG            B2
#
#     touchpoint_channel_clm      measure_source monthyear  \
# 548         Face to Face@0  veeva_interactions   2017-05
# 549         Face to Face@0  veeva_interactions   2017-05
# 550         Face to Face@1  veeva_interactions   2018-03
# 551         Face to Face@1  veeva_interactions   2018-03
# 552         Face to Face@1  veeva_interactions   2018-03
#
#                       tactic
# 548  NoMessage SGM NoMessage
# 549  NoMessage SGM NoMessage
# 550  NoMessage SGM NoMessage
# 551  NoMessage SGM NoMessage
# 552  NoMessage SGM NoMessage
# Random five data points
#                  product_id        date geo_country content_category  \
# 885425   a00G000000URsmCIAT  2017-09-27         ESP          Unknown
# 1920978  a00G000000URPpHIAX  2018-02-07         ESP          Unknown
# 1983227  a00G000000URPpmIAH  2019-07-17         ESP          Unknown
# 2270176  a00G000000URPpnIAH  2015-03-02         ESP          Unknown
# 188395   a00G000000Ux9H6IAJ  2018-01-31         ESP          Unknown
#
#         content_message_local content_message_global  \
# 885425              NoMessage              NoMessage
# 1920978             NoMessage              NoMessage
# 1983227             NoMessage              NoMessage
# 2270176             NoMessage              NoMessage
# 188395              NoMessage              NoMessage
#
#                                  product                          indication  \
# 885425                   Humira Axial_ES     Axial Spondyloarthritis (axSpA)
# 1920978                     Humira AR_ES           Rheumatoid Arthritis (RA)
# 1983227                     Humira MA_ES                       No indication
# 2270176  Viekirax/Exviera/Holkira_COM_ES                       No indication
# 188395               Humira CROHN_PED_ES  Pediatric Crohn's Disease (Ped CD)
#
#          therapeutic_area          account_id segment_quant  \
# 885425       Rheumatology  001G000001t2XYGIA2            B2
# 1920978      Rheumatology  001G0000022XyWgIAK            B2
# 1983227  Gastroenterology  001G000001tCWu5IAG            B2
# 2270176        Hepatology  001G000001tCWu5IAG            B2
# 188395   Gastroenterology  001G000001t314AIAQ            B1
#
#         touchpoint_channel_clm      measure_source monthyear  \
# 885425          Face to Face@0  veeva_interactions   2017-09
# 1920978         Face to Face@0  veeva_interactions   2018-02
# 1983227         Face to Face@0  veeva_interactions   2019-07
# 2270176         Face to Face@0  veeva_interactions   2015-03
# 188395          Face to Face@1  veeva_interactions   2018-01
#
#                           tactic
# 885425   NoMessage SGM NoMessage
# 1920978  NoMessage SGM NoMessage
# 1983227  NoMessage SGM NoMessage
# 2270176  NoMessage SGM NoMessage
# 188395   NoMessage SGM NoMessage
# Last five data points
#                  product_id        date geo_country content_category  \
# 2369667  a00G000000WC3a8IAD  2016-11-10         ESP          Unknown
# 2369668  a00G000000WC3a8IAD  2018-03-05         ESP          Unknown
# 2369669  a00G000000WC3a8IAD  2018-09-11         ESP          Unknown
# 2369670  a00G000000WC3a8IAD  2018-04-13         ESP          Unknown
# 2369671  a00G000000WmJIEIA3  2017-11-02         ESP          Unknown
#
#         content_message_local content_message_global                 product  \
# 2369667             NoMessage              NoMessage  Environment_CLL_KAM_ES
# 2369668             NoMessage              NoMessage  Environment_CLL_KAM_ES
# 2369669             NoMessage              NoMessage  Environment_CLL_KAM_ES
# 2369670             NoMessage              NoMessage  Environment_CLL_KAM_ES
# 2369671             NoMessage              NoMessage   Venetoclax_AML_MED_ES
#
#             indication therapeutic_area          account_id segment_quant  \
# 2369667  No indication      Hemato/Onco  001G000001tCWu5IAG            B2
# 2369668  No indication      Hemato/Onco  001G000001tCWu5IAG            B2
# 2369669  No indication      Hemato/Onco  001G000001tCWu5IAG            B2
# 2369670  No indication      Hemato/Onco  001G000001tCWu5IAG            B2
# 2369671  No indication      Hemato/Onco  001G000001tCWu5IAG            B2
#
#         touchpoint_channel_clm      measure_source monthyear  \
# 2369667         Face to Face@0  veeva_interactions   2016-11
# 2369668         Face to Face@0  veeva_interactions   2018-03
# 2369669         Face to Face@0  veeva_interactions   2018-09
# 2369670         Face to Face@0  veeva_interactions   2018-04
# 2369671         Face to Face@0  veeva_interactions   2017-11
#
#                           tactic
# 2369667  NoMessage SGM NoMessage
# 2369668  NoMessage SGM NoMessage
# 2369669  NoMessage SGM NoMessage
# 2369670  NoMessage SGM NoMessage
# 2369671  NoMessage SGM NoMessage
# Shape of  data set: (2261286, 15)
#
#
# Size of  data set: 33919290
#
#
# Data Types
# Note: All Non-numerical features are identified as objects in pandas
#                         Data Type
# product_id                 object
# date                       object
# geo_country                object
# content_category           object
# content_message_local      object
# content_message_global     object
# product                    object
# indication                 object
# therapeutic_area           object
# account_id                 object
# segment_quant              object
# touchpoint_channel_clm     object
# measure_source             object
# monthyear               period[M]
# tactic                     object
# Column(s) {'date'} should be in Datetime format. Use the [to_date] function to convert to Pandas Datetime format
#
#
# Numerical Features in Data set
# []
#
#
# Categorical Features in Data set
# ['product_id',
#  'date',
#  'geo_country',
#  'content_category',
#  'content_message_local',
#  'content_message_global',
#  'product',
#  'indication',
#  'therapeutic_area',
#  'account_id',
#  'segment_quant',
#  'touchpoint_channel_clm',
#  'measure_source',
#  'tactic']
# Statistical Description of Columns
#                 product_id        date geo_country content_category  \
# count              2261286     2261286     2261286          2261286
# unique                 191        2059           1               12
# top     a00G000000URPpMIAX  2020-02-25         ESP          Unknown
# freq                204442        5106     2261286          2238795
#
#        content_message_local content_message_global          product  \
# count                2261286                2261286          2261286
# unique                    26                     19              191
# top                NoMessage              NoMessage  Humira CROHN_ES
# freq                 2238795                2238795           204442
#
#            indication  therapeutic_area          account_id segment_quant  \
# count         2261286           2261286             2261286       2261286
# unique             35                21               12857            20
# top     No indication  Gastroenterology  001G000001tCWu5IAG            B2
# freq           767694            630664             1012423       1461483
#
#        touchpoint_channel_clm      measure_source monthyear  \
# count                 2261286             2261286   2261286
# unique                     10                   1        80
# top            Face to Face@0  veeva_interactions   2018-05
# freq                  1751778             2261286     61724
#
#                          tactic
# count                   2261286
# unique                       26
# top     NoMessage SGM NoMessage
# freq                    2238795
# Description of Categorical Features
#                           count unique                      top     freq
# product_id              2261286    191       a00G000000URPpMIAX   204442
# date                    2261286   2059               2020-02-25     5106
# geo_country             2261286      1                      ESP  2261286
# content_category        2261286     12                  Unknown  2238795
# content_message_local   2261286     26                NoMessage  2238795
# content_message_global  2261286     19                NoMessage  2238795
# product                 2261286    191          Humira CROHN_ES   204442
# indication              2261286     35            No indication   767694
# therapeutic_area        2261286     21         Gastroenterology   630664
# account_id              2261286  12857       001G000001tCWu5IAG  1012423
# segment_quant           2261286     20                       B2  1461483
# touchpoint_channel_clm  2261286     10           Face to Face@0  1751778
# measure_source          2261286      1       veeva_interactions  2261286
# tactic                  2261286     26  NoMessage SGM NoMessage  2238795
# Unique class Count of Categorical features
# <style  type="text/css" >
#     #T_7f3a6f1a_d28f_11ea_aaf3_025432626165row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 1.5%);
#         }    #T_7f3a6f1a_d28f_11ea_aaf3_025432626165row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }    #T_7f3a6f1a_d28f_11ea_aaf3_025432626165row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }    #T_7f3a6f1a_d28f_11ea_aaf3_025432626165row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }    #T_7f3a6f1a_d28f_11ea_aaf3_025432626165row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }    #T_7f3a6f1a_d28f_11ea_aaf3_025432626165row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }    #T_7f3a6f1a_d28f_11ea_aaf3_025432626165row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 1.5%);
#         }    #T_7f3a6f1a_d28f_11ea_aaf3_025432626165row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
#         }    #T_7f3a6f1a_d28f_11ea_aaf3_025432626165row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }    #T_7f3a6f1a_d28f_11ea_aaf3_025432626165row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_7f3a6f1a_d28f_11ea_aaf3_025432626165row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }    #T_7f3a6f1a_d28f_11ea_aaf3_025432626165row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }    #T_7f3a6f1a_d28f_11ea_aaf3_025432626165row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }    #T_7f3a6f1a_d28f_11ea_aaf3_025432626165row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }</style><table id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Unique Count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row0_col0" class="data row0 col0" >product_id</td>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row0_col1" class="data row0 col1" >191</td>
#             </tr>
#             <tr>
#                         <th id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row1_col0" class="data row1 col0" >date</td>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row1_col1" class="data row1 col1" >2059</td>
#             </tr>
#             <tr>
#                         <th id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row2_col0" class="data row2 col0" >geo_country</td>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row2_col1" class="data row2 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row3_col0" class="data row3 col0" >content_category</td>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row3_col1" class="data row3 col1" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row4_col0" class="data row4 col0" >content_message_local</td>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row4_col1" class="data row4 col1" >26</td>
#             </tr>
#             <tr>
#                         <th id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row5_col0" class="data row5 col0" >content_message_global</td>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row5_col1" class="data row5 col1" >19</td>
#             </tr>
#             <tr>
#                         <th id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row6_col0" class="data row6 col0" >product</td>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row6_col1" class="data row6 col1" >191</td>
#             </tr>
#             <tr>
#                         <th id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row7_col0" class="data row7 col0" >indication</td>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row7_col1" class="data row7 col1" >35</td>
#             </tr>
#             <tr>
#                         <th id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row8_col0" class="data row8 col0" >therapeutic_area</td>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row8_col1" class="data row8 col1" >21</td>
#             </tr>
#             <tr>
#                         <th id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row9_col0" class="data row9 col0" >account_id</td>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row9_col1" class="data row9 col1" >12857</td>
#             </tr>
#             <tr>
#                         <th id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row10_col0" class="data row10 col0" >segment_quant</td>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row10_col1" class="data row10 col1" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row11_col0" class="data row11 col0" >touchpoint_channel_clm</td>
#                         <td id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165row11_col1" class="data row11 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_7f3a6f1a_d28f_11ea_aaf3_025432626165level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_7
# Missing Values in Data
#                   features  missing_counts  missing_percent
# 0               product_id               0              0.0
# 1                     date               0              0.0
# 2              geo_country               0              0.0
# 3         content_category               0              0.0
# 4    content_message_local               0              0.0
# 5   content_message_global               0              0.0
# 6                  product               0              0.0
# 7               indication               0              0.0
# 8         therapeutic_area               0              0.0
# 9               account_id               0              0.0
# 10           segment_quant               0              0.0
# 11  touchpoint_channel_clm               0              0.0
# 12          measure_source               0              0.0
# 13               monthyear               0              0.0
# 14                  tactic               0              0.0
# Pearson Correlation
# Empty DataFrame
# Columns: []
# Index: []
#
#
# Kendall Correlation
# Empty DataFrame
# Columns: []
# Index: []
#
#
# Spearman Correlation
# Empty DataFrame
# Columns: []
# Index: []
#
#
# Bivariant Stats between categorical features
# Number of unique values too large
# Number of unique values too large
# Frequency table
# ============================
# content_category  AbbVie or Brand Value  Adherence  Clinical Trial Design  \
# geo_country
# ESP                                1413        404                      2
#
# content_category  Disease Information  Dosing and Administration  Efficacy  \
# geo_country
# ESP                               132                       5824      6537
#
# content_category  Guidelines and Treatment Paradigm  \
# geo_country
# ESP                                               8
#
# content_category  Key Message Category does not apply  Mode of Action  \
# geo_country
# ESP                                              2334            5638
#
# content_category  Patient Support Programs  Safety  Unknown
# geo_country
# ESP                                     39     160  2238795
# ============================
# ChiSquare test statistic:  0.0
# p-value:  1.0
#
#
# Number of unique values too large
# Number of unique values too large
# Number of unique values too large
# Number of unique values too large
# Number of unique values too large
# Number of unique values too large
# Number of unique values too large
# Number of unique values too large
# None

# %%
data['frequency_of_tactic'] = 1

# %%
grouped1 = data.groupby(by = ['product_id','monthyear', 'tactic'])['frequency_of_tactic'].sum().reset_index()

# No 'content_category', 'content_message_local', 'content_message_global', 'product', 'indication', 'therapeutic_area', 'segment_quant', 'touchpoint_channel_clm','account_id'

# %%
grouped2 = data.groupby(by = ['product_id','monthyear','content_category', 'content_message_local',
       'content_message_global', 'product', 'indication', 'therapeutic_area', 'segment_quant', 'touchpoint_channel_clm',
       'tactic', 'account_id'])['frequency_of_tactic'].sum().reset_index()

# %%
grouped3 = data.groupby(by = ['product_id','monthyear','content_category', 'content_message_local',
       'content_message_global', 'product', 'indication', 'therapeutic_area', 'segment_quant', 'touchpoint_channel_clm',
       'tactic'])['frequency_of_tactic'].sum().reset_index()

# No 'account_id'

# %%
#grouped = data.groupby(by = ['product_id','content_category', 'content_message_local',
#       'content_message_global', 'product', 'indication', 'therapeutic_area', 'segment_quant', 'touchpoint_channel_clm',
#       'content_message_concat', 'monthyear'])['frequency_of_tactic'].sum().reset_index()

# %%
grouped1['product_id'].value_counts()
# Out:
# a00G000000URPppIAH    79
# a00G000000URPpMIAX    79
# a00G000000URPpmIAH    78
# a00G000000URPpGIAX    78
# a00G000000URPplIAH    75
#                       ..
# a000Y00001Cirg6QAB     1
# a000Y00001CirgKQAR     1
# a000Y00001CirgLQAR     1
# a00G000000WC3a9IAD     1
# a000Y00000GBAq2QAH     1
# Name: product_id, Length: 191, dtype: int64

# %%
grouped2['product_id'].value_counts()
# Out:
# a00G000000URPpNIAX    59694
# a00G000000URPpGIAX    57163
# a00G000000URPpMIAX    57146
# a00G000000URPpHIAX    56298
# a00G000000URPplIAH    47210
#                       ...
# a00G000000WBsrxIAD        1
# a00G000000WlfXTIAZ        1
# a00G000000UTNUVIA5        1
# a000Y00001CirfsQAB        1
# a00G000000UTNUeIAP        1
# Name: product_id, Length: 191, dtype: int64

# %%
grouped3['product_id'].value_counts()
# Out:
# a00G000000URPpNIAX    1605
# a00G000000URPpGIAX    1581
# a00G000000URPpMIAX    1548
# a00G000000URPppIAH    1330
# a00G000000URPpkIAH    1277
#                       ...
# a00G000000UTNUnIAP       1
# a00G000000UTNUWIA5       1
# a00G000000UTb2hIAD       1
# a000Y00001Cirg6QAB       1
# a00G000000UTNUUIA5       1
# Name: product_id, Length: 191, dtype: int64

# %%
grouped_data=grouped2

# %%
values = dict(grouped_data['tactic'].value_counts())

# %%
list_of_diff_tactics= values.keys()

# %%
counter = 1
mapper = dict()
for x in list_of_diff_tactics:
    mapper.update( {x : counter} )
    counter = counter + 1

# %%
 pd.DataFrame(mapper.items(), columns=['tactic', 'encoded_tactic'])
# Out:
#                                                tactic  encoded_tactic
# 0                             NoMessage SGM NoMessage               1
# 1   Aclaramiento completo duradero SGM Durable com...               2
# 2   Facilidad SGM Reliable 3-month dosing regardle...               3
# 3                     Seguridad SGM SKYRIZI/IL-23 MOA               4
# 4   Compromiso de Abbvie con la hematología SGM Gl...               5
# 5   Aclaramiento duradero con independencia de las...               6
# 6   Perspectivas en LLC SGM VEN regimens are the o...               7
# 7   Ibrutinib es una buena ocpion de rescate para ...               8
# 8   Aclaramiento duradero superior a Stelara SGM D...               9
# 9   Campaña Nada lo cambia todo SGM Nothing is Eve...              10
# 10  Adherencia SGM The potential of SKYRIZI can on...              11
# 11  Eficacia y tolerabilidad vs otros MOAs SGM SKY...              12
# 12  1º y único inhibidor potente y selectivo de BC...              13
# 13  VenR es la única alternativa que permite lFTD ...              14
# 14  Local Key Message does not apply SGM Global Ke...              15
# 15  Venclyxto tiene un perfil de seguridad predeci...              16
# 16  87% de los pac. con EMR-, permanecieron libres...              17
# 17  Más de la mitad de los pacientes con VenR cont...              18
# 18  FTD se traduce en: - Eas, - riesgo de aparició...              19
# 19  VenR demostró superioridad en SLP en todos los...              20
# 20  6 de cada 10 pacientes con Venclyxto + rituxim...              21
# 21  Aclaramiento duradero superior a adalimumab SG...              22
# 22            Skyrizi/IL-23 MOA SGM SKYRIZI/IL-23 MOA              23
# 23  Adherencia/AC SGM AC is specifically designed ...              24
# 24  Mejora de la CdV; Guias de tratamiento SGM Imp...              25
# 25  Diseño de los ensayos clínicos SGM Skyrizi tri...              26

# %%
grouped_data['encoded_tactic'] = grouped_data['tactic'].map(mapper)

# %%
grouped_data
# Out:
#                 product_id monthyear content_category content_message_local  \
# 0       a000Y000009zN7JQAU   2017-03          Unknown             NoMessage
# 1       a000Y000009zN7JQAU   2017-03          Unknown             NoMessage
# 2       a000Y000009zN7JQAU   2017-04          Unknown             NoMessage
# 3       a000Y000009zN7JQAU   2017-05          Unknown             NoMessage
# 4       a000Y000009zN7JQAU   2017-05          Unknown             NoMessage
# ...                    ...       ...              ...                   ...
# 550335  a00G000000WmiooIAB   2018-05          Unknown             NoMessage
# 550336  a00G000000WmiooIAB   2018-06          Unknown             NoMessage
# 550337  a00G000000WmiooIAB   2018-06          Unknown             NoMessage
# 550338  a00G000000WmiooIAB   2018-06          Unknown             NoMessage
# 550339  a00G000000WmiooIAB   2018-06          Unknown             NoMessage
#
#        content_message_global                              product  \
# 0                   NoMessage  GLECAPREVIR/PIBRENTASVIR_HCV_MED_ES
# 1                   NoMessage  GLECAPREVIR/PIBRENTASVIR_HCV_MED_ES
# 2                   NoMessage  GLECAPREVIR/PIBRENTASVIR_HCV_MED_ES
# 3                   NoMessage  GLECAPREVIR/PIBRENTASVIR_HCV_MED_ES
# 4                   NoMessage  GLECAPREVIR/PIBRENTASVIR_HCV_MED_ES
# ...                       ...                                  ...
# 550335              NoMessage                            AD_MED_ES
# 550336              NoMessage                            AD_MED_ES
# 550337              NoMessage                            AD_MED_ES
# 550338              NoMessage                            AD_MED_ES
# 550339              NoMessage                            AD_MED_ES
#
#            indication  therapeutic_area segment_quant touchpoint_channel_clm  \
# 0       No indication        Hepatology            B2         Face to Face@0
# 1       No indication        Hepatology            B2         Face to Face@0
# 2       No indication        Hepatology            B2         Face to Face@0
# 3       No indication        Hepatology            B2               E-mail@0
# 4       No indication        Hepatology            B2         Face to Face@0
# ...               ...               ...           ...                    ...
# 550335  No indication  Gastroenterology            B2            Telephone@0
# 550336  No indication  Gastroenterology            B2               E-mail@0
# 550337  No indication  Gastroenterology            B2         Face to Face@0
# 550338  No indication  Gastroenterology            B2         Face to Face@0
# 550339  No indication  Gastroenterology            B2         Face to Face@0
#
#                          tactic          account_id  frequency_of_tactic  \
# 0       NoMessage SGM NoMessage  001G000001tCWu5IAG                   28
# 1       NoMessage SGM NoMessage  001G000001viuVvIAI                    1
# 2       NoMessage SGM NoMessage  001G000001tCWu5IAG                   22
# 3       NoMessage SGM NoMessage  001G000001tCWu5IAG                    1
# 4       NoMessage SGM NoMessage  001G000001tCWu5IAG                   67
# ...                         ...                 ...                  ...
# 550335  NoMessage SGM NoMessage  001G000001tCWu5IAG                    2
# 550336  NoMessage SGM NoMessage  001G000001tCWu5IAG                    2
# 550337  NoMessage SGM NoMessage  001G000001t2wsHIAQ                    1
# 550338  NoMessage SGM NoMessage  001G000001t2zOJIAY                    1
# 550339  NoMessage SGM NoMessage  001G000001tCWu5IAG                   10
#
#         encoded_tactic
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# ...                ...
# 550335               1
# 550336               1
# 550337               1
# 550338               1
# 550339               1
#
# [550340 rows x 14 columns]

# %%
describe(data=grouped_data, name='', date_cols=None, show_categories=False, plot_missing='frequency_of_tactic', target = None)
# Out:
# First five data points
#            product_id monthyear content_category content_message_local  \
# 0  a000Y000009zN7JQAU   2017-03          Unknown             NoMessage
# 1  a000Y000009zN7JQAU   2017-03          Unknown             NoMessage
# 2  a000Y000009zN7JQAU   2017-04          Unknown             NoMessage
# 3  a000Y000009zN7JQAU   2017-05          Unknown             NoMessage
# 4  a000Y000009zN7JQAU   2017-05          Unknown             NoMessage
#
#   content_message_global                              product     indication  \
# 0              NoMessage  GLECAPREVIR/PIBRENTASVIR_HCV_MED_ES  No indication
# 1              NoMessage  GLECAPREVIR/PIBRENTASVIR_HCV_MED_ES  No indication
# 2              NoMessage  GLECAPREVIR/PIBRENTASVIR_HCV_MED_ES  No indication
# 3              NoMessage  GLECAPREVIR/PIBRENTASVIR_HCV_MED_ES  No indication
# 4              NoMessage  GLECAPREVIR/PIBRENTASVIR_HCV_MED_ES  No indication
#
#   therapeutic_area segment_quant touchpoint_channel_clm  \
# 0       Hepatology            B2         Face to Face@0
# 1       Hepatology            B2         Face to Face@0
# 2       Hepatology            B2         Face to Face@0
# 3       Hepatology            B2               E-mail@0
# 4       Hepatology            B2         Face to Face@0
#
#                     tactic          account_id  frequency_of_tactic  \
# 0  NoMessage SGM NoMessage  001G000001tCWu5IAG                   28
# 1  NoMessage SGM NoMessage  001G000001viuVvIAI                    1
# 2  NoMessage SGM NoMessage  001G000001tCWu5IAG                   22
# 3  NoMessage SGM NoMessage  001G000001tCWu5IAG                    1
# 4  NoMessage SGM NoMessage  001G000001tCWu5IAG                   67
#
#    encoded_tactic
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# Random five data points
#                 product_id monthyear content_category content_message_local  \
# 46404   a001v00001cTVB8AAO   2019-09          Unknown             NoMessage
# 525063  a00G000000URsmDIAT   2017-05          Unknown             NoMessage
# 37537   a001v00001cTVAVAA4   2020-04          Unknown             NoMessage
# 194514  a00G000000URPpHIAX   2018-05          Unknown             NoMessage
# 190507  a00G000000URPpHIAX   2018-01          Unknown             NoMessage
#
#        content_message_global                    product  \
# 46404               NoMessage              Venclyxto_CLL
# 525063              NoMessage          Humira Uveítis_ES
# 37537               NoMessage  Rheumatoid Arthritis (RA)
# 194514              NoMessage               Humira AR_ES
# 190507              NoMessage               Humira AR_ES
#
#                                 indication     therapeutic_area segment_quant  \
# 46404   Chronic Lymphocytic Leukemia (CLL)  Oncology Hematology            C3
# 525063              Non-infectious Uveitis        Ophthalmology            B1
# 37537            Rheumatoid Arthritis (RA)         Rheumatology            C2
# 194514           Rheumatoid Arthritis (RA)         Rheumatology            B3
# 190507           Rheumatoid Arthritis (RA)         Rheumatology            B2
#
#        touchpoint_channel_clm                   tactic          account_id  \
# 46404          Face to Face@0  NoMessage SGM NoMessage  001G000001t38w2IAA
# 525063         Face to Face@0  NoMessage SGM NoMessage  001G000001t2WwUIAU
# 37537                E-mail@0  NoMessage SGM NoMessage  001G000001t2wGkIAI
# 194514         Face to Face@0  NoMessage SGM NoMessage  001G000001t2ss6IAA
# 190507         Face to Face@0  NoMessage SGM NoMessage  001G000001t2rEBIAY
#
#         frequency_of_tactic  encoded_tactic
# 46404                     2               1
# 525063                    4               1
# 37537                     1               1
# 194514                    1               1
# 190507                    1               1
# Last five data points
#                 product_id monthyear content_category content_message_local  \
# 550335  a00G000000WmiooIAB   2018-05          Unknown             NoMessage
# 550336  a00G000000WmiooIAB   2018-06          Unknown             NoMessage
# 550337  a00G000000WmiooIAB   2018-06          Unknown             NoMessage
# 550338  a00G000000WmiooIAB   2018-06          Unknown             NoMessage
# 550339  a00G000000WmiooIAB   2018-06          Unknown             NoMessage
#
#        content_message_global    product     indication  therapeutic_area  \
# 550335              NoMessage  AD_MED_ES  No indication  Gastroenterology
# 550336              NoMessage  AD_MED_ES  No indication  Gastroenterology
# 550337              NoMessage  AD_MED_ES  No indication  Gastroenterology
# 550338              NoMessage  AD_MED_ES  No indication  Gastroenterology
# 550339              NoMessage  AD_MED_ES  No indication  Gastroenterology
#
#        segment_quant touchpoint_channel_clm                   tactic  \
# 550335            B2            Telephone@0  NoMessage SGM NoMessage
# 550336            B2               E-mail@0  NoMessage SGM NoMessage
# 550337            B2         Face to Face@0  NoMessage SGM NoMessage
# 550338            B2         Face to Face@0  NoMessage SGM NoMessage
# 550339            B2         Face to Face@0  NoMessage SGM NoMessage
#
#                 account_id  frequency_of_tactic  encoded_tactic
# 550335  001G000001tCWu5IAG                    2               1
# 550336  001G000001tCWu5IAG                    2               1
# 550337  001G000001t2wsHIAQ                    1               1
# 550338  001G000001t2zOJIAY                    1               1
# 550339  001G000001tCWu5IAG                   10               1
# Shape of  data set: (550340, 14)
#
#
# Size of  data set: 7704760
#
#
# Data Types
# Note: All Non-numerical features are identified as objects in pandas
#                         Data Type
# product_id                 object
# monthyear               period[M]
# content_category           object
# content_message_local      object
# content_message_global     object
# product                    object
# indication                 object
# therapeutic_area           object
# segment_quant              object
# touchpoint_channel_clm     object
# tactic                     object
# account_id                 object
# frequency_of_tactic         int64
# encoded_tactic              int64
# Numerical Features in Data set
# ['frequency_of_tactic', 'encoded_tactic']
#
#
# Categorical Features in Data set
# ['product_id',
#  'content_category',
#  'content_message_local',
#  'content_message_global',
#  'product',
#  'indication',
#  'therapeutic_area',
#  'segment_quant',
#  'touchpoint_channel_clm',
#  'tactic',
#  'account_id']
# Statistical Description of Columns
#        frequency_of_tactic  encoded_tactic
# count        550340.000000   550340.000000
# mean              4.108889        1.100060
# std              64.308909        0.917756
# min               1.000000        1.000000
# 25%               1.000000        1.000000
# 50%               1.000000        1.000000
# 75%               2.000000        1.000000
# max           12172.000000       26.000000
# Description of Categorical Features
#                          count unique                      top    freq
# product_id              550340    191       a00G000000URPpNIAX   59694
# content_category        550340     12                  Unknown  536493
# content_message_local   550340     26                NoMessage  536493
# content_message_global  550340     19                NoMessage  536493
# product                 550340    191            Humira PSO_ES   59694
# indication              550340     35           Psoriasis (PS)   83452
# therapeutic_area        550340     21         Gastroenterology  135235
# segment_quant           550340     20                       B2  204708
# touchpoint_channel_clm  550340     10           Face to Face@0  466293
# tactic                  550340     26  NoMessage SGM NoMessage  536493
# account_id              550340  12857       001G000001tCWu5IAG    6340
# Unique class Count of Categorical features
# <style  type="text/css" >
#     #T_8d3b2464_d28f_11ea_af64_025432626165row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 1.5%);
#         }    #T_8d3b2464_d28f_11ea_af64_025432626165row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }    #T_8d3b2464_d28f_11ea_af64_025432626165row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }    #T_8d3b2464_d28f_11ea_af64_025432626165row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }    #T_8d3b2464_d28f_11ea_af64_025432626165row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 1.5%);
#         }    #T_8d3b2464_d28f_11ea_af64_025432626165row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
#         }    #T_8d3b2464_d28f_11ea_af64_025432626165row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }    #T_8d3b2464_d28f_11ea_af64_025432626165row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }    #T_8d3b2464_d28f_11ea_af64_025432626165row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }    #T_8d3b2464_d28f_11ea_af64_025432626165row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }    #T_8d3b2464_d28f_11ea_af64_025432626165row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }</style><table id="T_8d3b2464_d28f_11ea_af64_025432626165" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Unique Count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8d3b2464_d28f_11ea_af64_025432626165level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row0_col0" class="data row0 col0" >product_id</td>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row0_col1" class="data row0 col1" >191</td>
#             </tr>
#             <tr>
#                         <th id="T_8d3b2464_d28f_11ea_af64_025432626165level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row1_col0" class="data row1 col0" >content_category</td>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row1_col1" class="data row1 col1" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_8d3b2464_d28f_11ea_af64_025432626165level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row2_col0" class="data row2 col0" >content_message_local</td>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row2_col1" class="data row2 col1" >26</td>
#             </tr>
#             <tr>
#                         <th id="T_8d3b2464_d28f_11ea_af64_025432626165level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row3_col0" class="data row3 col0" >content_message_global</td>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row3_col1" class="data row3 col1" >19</td>
#             </tr>
#             <tr>
#                         <th id="T_8d3b2464_d28f_11ea_af64_025432626165level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row4_col0" class="data row4 col0" >product</td>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row4_col1" class="data row4 col1" >191</td>
#             </tr>
#             <tr>
#                         <th id="T_8d3b2464_d28f_11ea_af64_025432626165level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row5_col0" class="data row5 col0" >indication</td>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row5_col1" class="data row5 col1" >35</td>
#             </tr>
#             <tr>
#                         <th id="T_8d3b2464_d28f_11ea_af64_025432626165level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row6_col0" class="data row6 col0" >therapeutic_area</td>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row6_col1" class="data row6 col1" >21</td>
#             </tr>
#             <tr>
#                         <th id="T_8d3b2464_d28f_11ea_af64_025432626165level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row7_col0" class="data row7 col0" >segment_quant</td>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row7_col1" class="data row7 col1" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_8d3b2464_d28f_11ea_af64_025432626165level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row8_col0" class="data row8 col0" >touchpoint_channel_clm</td>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row8_col1" class="data row8 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_8d3b2464_d28f_11ea_af64_025432626165level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row9_col0" class="data row9 col0" >tactic</td>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row9_col1" class="data row9 col1" >26</td>
#             </tr>
#             <tr>
#                         <th id="T_8d3b2464_d28f_11ea_af64_025432626165level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row10_col0" class="data row10 col0" >account_id</td>
#                         <td id="T_8d3b2464_d28f_11ea_af64_025432626165row10_col1" class="data row10 col1" >12857</td>
#             </tr>
#     </tbody></table>
# Missing Values in Data
#                   features  missing_counts  missing_percent
# 0               product_id               0              0.0
# 1                monthyear               0              0.0
# 2         content_category               0              0.0
# 3    content_message_local               0              0.0
# 4   content_message_global               0              0.0
# 5                  product               0              0.0
# 6               indication               0              0.0
# 7         therapeutic_area               0              0.0
# 8            segment_quant               0              0.0
# 9   touchpoint_channel_clm               0              0.0
# 10                  tactic               0              0.0
# 11              account_id               0              0.0
# 12     frequency_of_tactic               0              0.0
# 13          encoded_tactic               0              0.0
# Pearson Correlation
#                      frequency_of_tactic  encoded_tactic
# frequency_of_tactic             1.000000       -0.004267
# encoded_tactic                 -0.004267        1.000000
#
#
# Kendall Correlation
#                      frequency_of_tactic  encoded_tactic
# frequency_of_tactic             1.000000       -0.050233
# encoded_tactic                 -0.050233        1.000000
#
#
# Spearman Correlation
#                      frequency_of_tactic  encoded_tactic
# frequency_of_tactic             1.000000       -0.054648
# encoded_tactic                 -0.054648        1.000000
#
#
# Bivariant Stats between categorical features
# Number of unique values too large
# None

# %%
grouped_data['month'] = grouped_data['monthyear'].dt.month

# %%
grouped_data['year'] = grouped_data['monthyear'].dt.year

# %%
new_data1 = grouped_data[grouped_data['product']=='Skyrizi_PS']

# %%
new_data2 = grouped_data[grouped_data['product']=='Skyrizi_KAM']

# %%
new_data1 = new_data1.drop(['product_id', 'monthyear'], axis=1)

# %%
new_data2 = new_data2.drop(['product_id', 'monthyear'], axis=1)

# %%
new_data1 = encode_data(new_data1, method='binary')

# %%
new_data2 = encode_data(new_data2, method='binary')

# %%
new_data1 = new_data1.drop('tactic', axis=1)

# %%
#new_data2 = new_data2.drop('tactic', axis=1)

# %%
print('Skyrizi_PS')
sns.heatmap(new_data1.corr(), annot=True)
# Out:
# Skyrizi_PS

# %%
print('Skyrizi_KAM')
sns.heatmap(new_data2.corr(), annot=True)
# Out:
# Skyrizi_KAM

# %%
print('Skyrizi_PS')
new_data1.columns
# Out:
# Skyrizi_PS
# Index(['content_category', 'content_message_local', 'content_message_global',
#        'product_0', 'indication_0', 'therapeutic_area_0', 'segment_quant',
#        'touchpoint_channel_clm', 'account_id', 'frequency_of_tactic',
#        'encoded_tactic', 'month', 'year', 'Date'],
#       dtype='object')

# %%
print('Skyrizi_KAM')
new_data2.columns
# Out:
# Skyrizi_KAM
# Index(['content_category_0', 'content_message_local_0',
#        'content_message_global_0', 'product_0', 'indication_0',
#        'therapeutic_area_0', 'segment_quant_0', 'touchpoint_channel_clm_0',
#        'touchpoint_channel_clm_1', 'touchpoint_channel_clm_2', 'tactic_0',
#        'account_id_0', 'frequency_of_tactic', 'encoded_tactic_0', 'month',
#        'year', 'Date'],
#       dtype='object')

# %%
def standardscaler(data, cols = None):
    ''' 
    It is a standard normalization technique use when using machine learning models that assusme a normal/gaussian distribution.
    Models like Linear Regression, Gaussian Naive Bayes etc.
    -------------
        data: DataFrame, named Series
            Data set to perform operation on. It advisable not to scale/normalise the target variable.
        col: list of str
            columns in form of a list to scale/normalise. If not parsed, it scales/normalises the entire dataframe
        Returns:
    --------
        DataFrame of the scaled/normalised data/columns.
        
    It is used in the scale_normalise_data. It can also be used alone.
     '''
    if cols is not None:
        
        s_scaler = StandardScaler()
        data[cols] = s_scaler.fit_transform(data[cols])
        
        
    else:
        col_names = data.columns
        s_scaler = StandardScaler()
        df_s = s_scaler.fit_transform(data)
        data = pd.DataFrame(df_s, columns=col_names)
    
    return data

# %%
import statsmodels.api as sm
y = new_data1['frequency_of_tactic']
X = standardscaler(new_data1.drop('frequency_of_tactic', axis=1))

model = sm.OLS(y, X)
results = model.fit()
results.params

# %%
results.tvalues

# %%
print(results.summary())

# %% [markdown]
# ## Analysis of Content Message Concat

# %%
grouped_data['product_id'].value_counts()
# Out:
# a00G000000URPpNIAX    59694
# a00G000000URPpGIAX    57163
# a00G000000URPpMIAX    57146
# a00G000000URPpHIAX    56298
# a00G000000URPplIAH    47210
#                       ...
# a00G000000WBsrxIAD        1
# a00G000000WlfXTIAZ        1
# a00G000000UTNUVIA5        1
# a000Y00001CirfsQAB        1
# a00G000000UTNUeIAP        1
# Name: product_id, Length: 191, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import datetime



df1 = grouped_data[['encoded_tactic','frequency_of_tactic','monthyear']]
df1.index = df1['monthyear']
pt = pd.pivot_table(df1, index=df1.index.month, columns=df1['encoded_tactic'], aggfunc='sum')['frequency_of_tactic']

ax = plt.figure().add_subplot(111)
ax.plot(pt)

ticklabels = [datetime.date(1900, item, 1).strftime('%b') for item in pt.index]
ax.set_xticks(np.arange(1,13))
ax.set_xticklabels(ticklabels) #add monthlabels to the xaxis

ax.legend(pt.columns.tolist(), loc='center left', bbox_to_anchor=(1, .5)) #add the column names as legend.
plt.tight_layout(rect=[0, 0, 0.85, 1])

plt.show()

# %%
counter = 1
mapper = dict()
for x in list_of_diff_tactics:
    mapper.update( {x : f'tactic{counter}'} )
    counter = counter + 1

# %%
grouped_data['encoded_tactic'] = grouped_data['tactic'].map(mapper)

# %%
grouped_data['encoded_tactic']
# Out:
# 0         tactic1
# 1         tactic1
# 2         tactic1
# 3         tactic1
# 4         tactic1
#            ...
# 550335    tactic1
# 550336    tactic1
# 550337    tactic1
# 550338    tactic1
# 550339    tactic1
# Name: encoded_tactic, Length: 550340, dtype: object

# %%
grouped_data['Date'] = grouped_data['monthyear'].values.astype('datetime64[M]')

# %%
grouped_data['product_id'].value_counts()
# Out:
# a00G000000URPpNIAX    59694
# a00G000000URPpGIAX    57163
# a00G000000URPpMIAX    57146
# a00G000000URPpHIAX    56298
# a00G000000URPplIAH    47210
#                       ...
# a00G000000WBsrxIAD        1
# a00G000000WlfXTIAZ        1
# a00G000000UTNUVIA5        1
# a000Y00001CirfsQAB        1
# a00G000000UTNUeIAP        1
# Name: product_id, Length: 191, dtype: int64

# %% [markdown]
# ## Content Message Concat Analysis for Product a00G000000URPpNIAX

# %%
df1 = grouped_data[grouped_data['product_id']=='a00G000000URPpNIAX']

# %%
hue_order = list(dict(df1['encoded_tactic'].value_counts()).keys())

# %%
df1['encoded_tactic'].value_counts()
# Out:
# tactic1    59694
# Name: encoded_tactic, dtype: int64

# %%
fig, ax = plt.subplots()
sns.lineplot(data=df1, x='Date', y='frequency_of_tactic', hue='encoded_tactic', ax=ax, estimator='sum',ci = None)
#ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter("%Y-%M"))
fig.autofmt_xdate()

# %%
df1.groupby(['monthyear', 'encoded_tactic'])['frequency_of_tactic'].sum().unstack()
# Out:
# encoded_tactic  tactic1
# monthyear
# 2014-01            1872
# 2014-02            2569
# 2014-03            2694
# 2014-04            1990
# 2014-05            1949
# ...                 ...
# 2019-03            5533
# 2019-04            3525
# 2019-05            4448
# 2019-06            2161
# 2019-07             647
#
# [67 rows x 1 columns]

# %% [markdown]
# ## Content Message Concat Analysis for Product a00G000000URPpGIAX

# %%
df2 = grouped_data[grouped_data['product_id']=='a00G000000URPpGIAX']

# %%
len(list(dict(df2['encoded_tactic'].value_counts()).keys()))
# Out:
# 1

# %%
fig, ax = plt.subplots()
sns.lineplot(data=df2, x='Date', y='frequency_of_tactic', hue='encoded_tactic', ax=ax, estimator='sum',ci = None)
#ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter("%Y-%M"))
fig.autofmt_xdate()

# %%
df2.groupby(['monthyear', 'encoded_tactic'])['frequency_of_tactic'].sum().unstack()
# Out:
# encoded_tactic  tactic1
# monthyear
# 2014-01            1397
# 2014-02            1508
# 2014-03            1566
# 2014-04             908
# 2014-05            1342
# ...                 ...
# 2020-02            1350
# 2020-03             651
# 2020-04             212
# 2020-05             531
# 2020-06             565
#
# [78 rows x 1 columns]

# %% [markdown]
# ## Content Message Concat Analysis for Product a00G000000URPpMIAX

# %%
df3 = grouped_data[grouped_data['product_id']=='a00G000000URPpMIAX']

# %%
len(list(dict(df3['encoded_tactic'].value_counts()).keys()))
# Out:
# 1

# %%
fig, ax = plt.subplots()
sns.lineplot(data=df3, x='Date', y='frequency_of_tactic',ci = None, hue='encoded_tactic', ax=ax, estimator='sum')
#ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter("%Y-%M"))
fig.autofmt_xdate()

# %%
df3.groupby(['monthyear', 'encoded_tactic'])['frequency_of_tactic'].sum().unstack()
# Out:
# encoded_tactic  tactic1
# monthyear
# 2013-12               4
# 2014-01            1210
# 2014-02            1672
# 2014-03            1628
# 2014-04            1354
# ...                 ...
# 2020-02            6925
# 2020-03            2990
# 2020-04             785
# 2020-05            1176
# 2020-06             770
#
# [79 rows x 1 columns]

# %% [markdown]
# ## Content Message Concat Analysis for Product a00G000000URPppIAH

# %%
df4 = grouped_data[grouped_data['product_id']=='a00G000000URPppIAH']

# %%
len(list(dict(df4['encoded_tactic'].value_counts()).keys()))
# Out:
# 1

# %%
fig, ax = plt.subplots()
sns.lineplot(data=df4, x='Date', y='frequency_of_tactic',ci = None, hue='encoded_tactic', ax=ax, estimator='sum')
#ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter("%Y-%M"))
fig.autofmt_xdate()

# %%
df4.groupby(['monthyear', 'encoded_tactic'])['frequency_of_tactic'].sum().unstack()
# Out:
# encoded_tactic  tactic1
# monthyear
# 2014-01            1133
# 2014-02            1518
# 2014-03            1135
# 2014-04            1093
# 2014-05            1391
# ...                 ...
# 2020-03            1074
# 2020-04             864
# 2020-05             717
# 2020-06             522
# 2020-07               1
#
# [79 rows x 1 columns]

# %% [markdown]
# ##  Content Message Concat Analysis for Product a00G000000URPpkIAH

# %%
df5 = grouped_data[grouped_data['product_id']=='a00G000000URPpkIAH']

# %%
len(list(dict(df5['encoded_tactic'].value_counts()).keys()))
# Out:
# 1

# %%
fig, ax = plt.subplots()
sns.lineplot(data=df5, x='Date', y='frequency_of_tactic',ci = None, hue='encoded_tactic', ax=ax, estimator='sum')
#ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter("%Y-%M"))
fig.autofmt_xdate()

# %%
df5.groupby(['monthyear', 'encoded_tactic'])['frequency_of_tactic'].sum().unstack()
# Out:
# encoded_tactic  tactic1
# monthyear
# 2015-06             160
# 2015-07             954
# 2015-08              81
# 2015-09            1291
# 2015-10             804
# ...                 ...
# 2020-02             807
# 2020-03             521
# 2020-04             128
# 2020-05             194
# 2020-06             177
#
# [61 rows x 1 columns]

# %% [markdown]
# ##  Content Message Concat Analysis for Product a001v00001wbtlnAAA

# %%
df6 = grouped_data[grouped_data['product_id']=='a001v00001wbtlnAAA']

# %%
len(list(dict(df6['encoded_tactic'].value_counts()).keys()))
# Out:
# 15

# %%
dict(df6['encoded_tactic'].value_counts())
# Out:
# {'tactic3': 3500,
#  'tactic2': 3500,
#  'tactic4': 3390,
#  'tactic6': 331,
#  'tactic9': 283,
#  'tactic10': 228,
#  'tactic11': 222,
#  'tactic12': 191,
#  'tactic1': 153,
#  'tactic15': 152,
#  'tactic22': 13,
#  'tactic24': 11,
#  'tactic23': 11,
#  'tactic25': 6,
#  'tactic26': 2}

# %%
value_list = ['tactic1',
 'tactic2',
 'tactic3',
 'tactic4',
 'tactic6']
df_1 = df6[df6['encoded_tactic'].isin(value_list)]

# %%
value_list = ['tactic9',
 'tactic10',
 'tactic11',
 'tactic12',
 'tactic15']
df_2 = df6[df6['encoded_tactic'].isin(value_list)]

# %%
value_list = ['tactic22',
 'tactic23',
 'tactic24',
 'tactic25',
 'tactic26']
df_3 = df6[df6['encoded_tactic'].isin(value_list)]

# %%
col = [df_1, df_2, df_3]

# %%
for x in col:
    fig, ax = plt.subplots()
    sns.lineplot(data=x, x='Date', y='frequency_of_tactic', hue='encoded_tactic', ax=ax, estimator='sum',ci = None)
    #ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter("%Y-%M"))
    fig.autofmt_xdate()

# %%
df6.groupby(['monthyear', 'encoded_tactic'])['frequency_of_tactic'].sum().unstack()
# Out:
# encoded_tactic  tactic1  tactic10  tactic11  tactic12  tactic15  tactic2  \
# monthyear
# 2020-03             NaN       NaN       NaN       NaN       NaN      1.0
# 2020-04            96.0       1.0      56.0       3.0       NaN   2351.0
# 2020-05            58.0      81.0     158.0       7.0      43.0   1398.0
# 2020-06           142.0     563.0     190.0     217.0     173.0   2097.0
# 2020-07             1.0       3.0       NaN       1.0       NaN      4.0
#
# encoded_tactic  tactic22  tactic23  tactic24  tactic25  tactic26  tactic3  \
# monthyear
# 2020-03              NaN       NaN       NaN       NaN       NaN      1.0
# 2020-04              7.0       2.0       1.0       1.0       NaN   2211.0
# 2020-05              4.0       2.0       4.0       2.0       2.0   1512.0
# 2020-06              2.0       8.0      34.0       5.0       NaN   1708.0
# 2020-07              NaN       NaN       NaN       NaN       NaN      1.0
#
# encoded_tactic  tactic4  tactic6  tactic9
# monthyear
# 2020-03             1.0      NaN      NaN
# 2020-04          2193.0     73.0     36.0
# 2020-05          1441.0     90.0     49.0
# 2020-06          1565.0    227.0    274.0
# 2020-07             1.0      1.0      1.0

# %% [markdown]
# ##  Content Message Concat Analysis for Product Skyrizi_KAM

# %%
df7 = grouped_data[grouped_data['product']=='Skyrizi_KAM']

# %%
df7
# Out:
#                product_id monthyear content_category content_message_local  \
# 94099  a001v000022LcG1AAK   2020-04          Unknown             NoMessage
# 94100  a001v000022LcG1AAK   2020-04          Unknown             NoMessage
# 94101  a001v000022LcG1AAK   2020-04          Unknown             NoMessage
# 94102  a001v000022LcG1AAK   2020-05          Unknown             NoMessage
# 94103  a001v000022LcG1AAK   2020-05          Unknown             NoMessage
# 94104  a001v000022LcG1AAK   2020-05          Unknown             NoMessage
# 94105  a001v000022LcG1AAK   2020-05          Unknown             NoMessage
# 94106  a001v000022LcG1AAK   2020-06          Unknown             NoMessage
# 94107  a001v000022LcG1AAK   2020-06          Unknown             NoMessage
# 94108  a001v000022LcG1AAK   2020-06          Unknown             NoMessage
# 94109  a001v000022LcG1AAK   2020-06          Unknown             NoMessage
#
#       content_message_global      product     indication therapeutic_area  \
# 94099              NoMessage  Skyrizi_KAM  No indication      Dermatology
# 94100              NoMessage  Skyrizi_KAM  No indication      Dermatology
# 94101              NoMessage  Skyrizi_KAM  No indication      Dermatology
# 94102              NoMessage  Skyrizi_KAM  No indication      Dermatology
# 94103              NoMessage  Skyrizi_KAM  No indication      Dermatology
# 94104              NoMessage  Skyrizi_KAM  No indication      Dermatology
# 94105              NoMessage  Skyrizi_KAM  No indication      Dermatology
# 94106              NoMessage  Skyrizi_KAM  No indication      Dermatology
# 94107              NoMessage  Skyrizi_KAM  No indication      Dermatology
# 94108              NoMessage  Skyrizi_KAM  No indication      Dermatology
# 94109              NoMessage  Skyrizi_KAM  No indication      Dermatology
#
#       segment_quant touchpoint_channel_clm                   tactic  \
# 94099            B2               E-mail@0  NoMessage SGM NoMessage
# 94100            B2            Telephone@0  NoMessage SGM NoMessage
# 94101            B2        Virtual/Video@0  NoMessage SGM NoMessage
# 94102            B2               E-mail@0  NoMessage SGM NoMessage
# 94103            B2         Face to Face@0  NoMessage SGM NoMessage
# 94104            B2            Telephone@0  NoMessage SGM NoMessage
# 94105            B2        Virtual/Video@0  NoMessage SGM NoMessage
# 94106            B2               E-mail@0  NoMessage SGM NoMessage
# 94107            B2         Face to Face@0  NoMessage SGM NoMessage
# 94108            B2            Telephone@0  NoMessage SGM NoMessage
# 94109            B2        Virtual/Video@0  NoMessage SGM NoMessage
#
#                account_id  frequency_of_tactic encoded_tactic  month  year  \
# 94099  001G000001tCWu5IAG                   60        tactic1      4  2020
# 94100  001G000001tCWu5IAG                   45        tactic1      4  2020
# 94101  001G000001tCWu5IAG                    4        tactic1      4  2020
# 94102  001G000001tCWu5IAG                  246        tactic1      5  2020
# 94103  001G000001tCWu5IAG                    4        tactic1      5  2020
# 94104  001G000001tCWu5IAG                  374        tactic1      5  2020
# 94105  001G000001tCWu5IAG                  131        tactic1      5  2020
# 94106  001G000001tCWu5IAG                  207        tactic1      6  2020
# 94107  001G000001tCWu5IAG                    9        tactic1      6  2020
# 94108  001G000001tCWu5IAG                  339        tactic1      6  2020
# 94109  001G000001tCWu5IAG                   58        tactic1      6  2020
#
#             Date
# 94099 2020-04-01
# 94100 2020-04-01
# 94101 2020-04-01
# 94102 2020-05-01
# 94103 2020-05-01
# 94104 2020-05-01
# 94105 2020-05-01
# 94106 2020-06-01
# 94107 2020-06-01
# 94108 2020-06-01
# 94109 2020-06-01

# %%
len(list(dict(df7['encoded_tactic'].value_counts()).keys()))
# Out:
# 1

# %%
fig, ax = plt.subplots()
sns.lineplot(data=df7, x='Date', y='frequency_of_tactic',ci = None, hue='encoded_tactic', ax=ax, estimator='sum')
#ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter("%Y-%M"))
fig.autofmt_xdate()

# %%
df7.groupby(['monthyear', 'encoded_tactic'])['frequency_of_tactic'].sum().unstack()
# Out:
# encoded_tactic  tactic1
# monthyear
# 2020-04             109
# 2020-05             755
# 2020-06             613

# %% [markdown]
# ##  Content Message Concat Analysis for Product Skyrizi_PS

# %%
df8 = grouped_data[grouped_data['product']=='Skyrizi_PS']

# %%
df8
# Out:
#                product_id monthyear           content_category  \
# 72578  a001v00001wbtlnAAA   2020-03  Dosing and Administration
# 72579  a001v00001wbtlnAAA   2020-03                   Efficacy
# 72580  a001v00001wbtlnAAA   2020-03             Mode of Action
# 72581  a001v00001wbtlnAAA   2020-04      AbbVie or Brand Value
# 72582  a001v00001wbtlnAAA   2020-04                  Adherence
# ...                   ...       ...                        ...
# 84566  a001v00001wbtlnAAA   2020-07                   Efficacy
# 84567  a001v00001wbtlnAAA   2020-07                   Efficacy
# 84568  a001v00001wbtlnAAA   2020-07             Mode of Action
# 84569  a001v00001wbtlnAAA   2020-07             Mode of Action
# 84570  a001v00001wbtlnAAA   2020-07                    Unknown
#
#                           content_message_local  \
# 72578                                 Facilidad
# 72579            Aclaramiento completo duradero
# 72580                                 Seguridad
# 72581               Campaña Nada lo cambia todo
# 72582                                Adherencia
# ...                                         ...
# 84566            Aclaramiento completo duradero
# 84567  Aclaramiento duradero superior a Stelara
# 84568    Eficacia y tolerabilidad vs otros MOAs
# 84569                                 Seguridad
# 84570                                 NoMessage
#
#                                   content_message_global     product  \
# 72578  Reliable 3-month dosing regardless of baseline...  Skyrizi_PS
# 72579                         Durable complete clearance  Skyrizi_PS
# 72580                                  SKYRIZI/IL-23 MOA  Skyrizi_PS
# 72581             Nothing is Everything/campaign summary  Skyrizi_PS
# 72582  The potential of SKYRIZI can only be achieved ...  Skyrizi_PS
# ...                                                  ...         ...
# 84566                         Durable complete clearance  Skyrizi_PS
# 84567              Durable clearance superior to Stelara  Skyrizi_PS
# 84568                                  SKYRIZI/IL-23 MOA  Skyrizi_PS
# 84569                                  SKYRIZI/IL-23 MOA  Skyrizi_PS
# 84570                                          NoMessage  Skyrizi_PS
#
#            indication therapeutic_area segment_quant touchpoint_channel_clm  \
# 72578  Psoriasis (PS)      Dermatology            C3               E-mail@0
# 72579  Psoriasis (PS)      Dermatology            C3               E-mail@0
# 72580  Psoriasis (PS)      Dermatology            C3               E-mail@0
# 72581  Psoriasis (PS)      Dermatology            B2               E-mail@0
# 72582  Psoriasis (PS)      Dermatology            A1               E-mail@0
# ...               ...              ...           ...                    ...
# 84566  Psoriasis (PS)      Dermatology            B2         Face to Face@1
# 84567  Psoriasis (PS)      Dermatology            B2         Face to Face@1
# 84568  Psoriasis (PS)      Dermatology            B2         Face to Face@1
# 84569  Psoriasis (PS)      Dermatology            B2         Face to Face@1
# 84570  Psoriasis (PS)      Dermatology            B2         Face to Face@0
#
#                                                   tactic          account_id  \
# 72578  Facilidad SGM Reliable 3-month dosing regardle...  001G000001t30WqIAI
# 72579  Aclaramiento completo duradero SGM Durable com...  001G000001t30WqIAI
# 72580                    Seguridad SGM SKYRIZI/IL-23 MOA  001G000001t30WqIAI
# 72581  Campaña Nada lo cambia todo SGM Nothing is Eve...  001G000001tCWu5IAG
# 72582  Adherencia SGM The potential of SKYRIZI can on...  001G000001t2rvnIAA
# ...                                                  ...                 ...
# 84566  Aclaramiento completo duradero SGM Durable com...  001G000001t356FIAQ
# 84567  Aclaramiento duradero superior a Stelara SGM D...  001G000001t356FIAQ
# 84568  Eficacia y tolerabilidad vs otros MOAs SGM SKY...  001G000001t356FIAQ
# 84569                    Seguridad SGM SKYRIZI/IL-23 MOA  001G000001t356FIAQ
# 84570                            NoMessage SGM NoMessage  001G000001t3BANIA2
#
#        frequency_of_tactic encoded_tactic  month  year       Date
# 72578                    1        tactic3      3  2020 2020-03-01
# 72579                    1        tactic2      3  2020 2020-03-01
# 72580                    1        tactic4      3  2020 2020-03-01
# 72581                    1       tactic10      4  2020 2020-04-01
# 72582                    1       tactic11      4  2020 2020-04-01
# ...                    ...            ...    ...   ...        ...
# 84566                    4        tactic2      7  2020 2020-07-01
# 84567                    1        tactic9      7  2020 2020-07-01
# 84568                    1       tactic12      7  2020 2020-07-01
# 84569                    1        tactic4      7  2020 2020-07-01
# 84570                    1        tactic1      7  2020 2020-07-01
#
# [11993 rows x 17 columns]

# %%
len(list(dict(df8['encoded_tactic'].value_counts()).keys()))
# Out:
# 15

# %%
dict(df8['encoded_tactic'].value_counts())
# Out:
# {'tactic3': 3500,
#  'tactic2': 3500,
#  'tactic4': 3390,
#  'tactic6': 331,
#  'tactic9': 283,
#  'tactic10': 228,
#  'tactic11': 222,
#  'tactic12': 191,
#  'tactic1': 153,
#  'tactic15': 152,
#  'tactic22': 13,
#  'tactic24': 11,
#  'tactic23': 11,
#  'tactic25': 6,
#  'tactic26': 2}

# %%
value_list = ['tactic1',
 'tactic2',
 'tactic3',
 'tactic4',
 'tactic6']
df_1 = df8[df8['encoded_tactic'].isin(value_list)]

# %%
value_list = ['tactic9',
 'tactic10',
 'tactic11',
 'tactic12',
 'tactic15']
df_2 = df8[df8['encoded_tactic'].isin(value_list)]

# %%
value_list = ['tactic22',
 'tactic23',
 'tactic24',
 'tactic25',
 'tactic26']
df_3 = df8[df8['encoded_tactic'].isin(value_list)]

# %%
col = [df_1, df_2, df_3]

# %%
for x in col:
    fig, ax = plt.subplots()
    sns.lineplot(data=x, x='Date', y='frequency_of_tactic', hue='encoded_tactic', ax=ax, estimator='sum',ci = None)
    #ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter("%Y-%M"))
    fig.autofmt_xdate()

# %% [markdown]
# ### Tactic and Actual Message

# %%
pd.DataFrame(mapper.items(), columns=['tactic', 'encoded_tactic'])
# Out:
#                                                tactic encoded_tactic
# 0                             NoMessage SGM NoMessage        tactic1
# 1   Aclaramiento completo duradero SGM Durable com...        tactic2
# 2   Facilidad SGM Reliable 3-month dosing regardle...        tactic3
# 3                     Seguridad SGM SKYRIZI/IL-23 MOA        tactic4
# 4   Compromiso de Abbvie con la hematología SGM Gl...        tactic5
# 5   Aclaramiento duradero con independencia de las...        tactic6
# 6   Perspectivas en LLC SGM VEN regimens are the o...        tactic7
# 7   Ibrutinib es una buena ocpion de rescate para ...        tactic8
# 8   Aclaramiento duradero superior a Stelara SGM D...        tactic9
# 9   Campaña Nada lo cambia todo SGM Nothing is Eve...       tactic10
# 10  Adherencia SGM The potential of SKYRIZI can on...       tactic11
# 11  Eficacia y tolerabilidad vs otros MOAs SGM SKY...       tactic12
# 12  1º y único inhibidor potente y selectivo de BC...       tactic13
# 13  VenR es la única alternativa que permite lFTD ...       tactic14
# 14  Local Key Message does not apply SGM Global Ke...       tactic15
# 15  Venclyxto tiene un perfil de seguridad predeci...       tactic16
# 16  87% de los pac. con EMR-, permanecieron libres...       tactic17
# 17  Más de la mitad de los pacientes con VenR cont...       tactic18
# 18  FTD se traduce en: - Eas, - riesgo de aparició...       tactic19
# 19  VenR demostró superioridad en SLP en todos los...       tactic20
# 20  6 de cada 10 pacientes con Venclyxto + rituxim...       tactic21
# 21  Aclaramiento duradero superior a adalimumab SG...       tactic22
# 22            Skyrizi/IL-23 MOA SGM SKYRIZI/IL-23 MOA       tactic23
# 23  Adherencia/AC SGM AC is specifically designed ...       tactic24
# 24  Mejora de la CdV; Guias de tratamiento SGM Imp...       tactic25
# 25  Diseño de los ensayos clínicos SGM Skyrizi tri...       tactic26
